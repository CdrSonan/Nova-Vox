# %%
import math
import numpy
import torch
import torch.nn as nn
import torchaudio
torchaudio.set_audio_backend("soundfile")
import matplotlib.pyplot as plt
# Out:
# C:\Users\Jokla\anaconda3\lib\site-packages\torchaudio\extension\extension.py:13: UserWarning: torchaudio C++ extension is not available.
#   warnings.warn('torchaudio C++ extension is not available.')

# %%
class AudioSample:
    def __init__(self, filepath):
        loadedData = torchaudio.load(filepath)
        self.waveform = loadedData[0][0]
        self.sampleRate = loadedData[1]
        del loadedData
        self.pitchDeltas = torch.tensor([], dtype = int)
        self.pitchBorders = torch.tensor([], dtype = int)
        self.Pitch = torch.tensor([0], dtype = int)
        self.spectra = torch.tensor([[]], dtype = float)
        self.spectrum = torch.tensor([], dtype = float)
        self.excitation = torch.tensor([], dtype = float) #replace with periodic and aperiodic excitation once implemented
        
    def CalculatePitch(self, expectedPitch, searchRange = 0.2):
        batchSize = math.floor((1. + searchRange) * self.sampleRate / expectedPitch)
        lowerSearchLimit = math.floor((1. - searchRange) * self.sampleRate / expectedPitch)
        batchStart = 0
        while batchStart + batchSize <= self.waveform.size()[0] - batchSize:
            sample = torch.index_select(self.waveform, 0, torch.linspace(batchStart, batchStart + batchSize, batchSize, dtype = int))
            zeroTransitions = torch.tensor([], dtype = int)
            for i in range(lowerSearchLimit, batchSize):
                if (sample[i-1] < 0) and (sample[i] > 0):
                    zeroTransitions = torch.cat([zeroTransitions, torch.tensor([i])], 0)
            error = math.inf
            delta = math.floor(self.sampleRate / expectedPitch)
            for i in zeroTransitions:
                shiftedSample = torch.index_select(self.waveform, 0, torch.linspace(batchStart + i.item(), batchStart + batchSize + i.item(), batchSize, dtype = int))
                newError = torch.sum(torch.pow(sample - shiftedSample, 2))
                if error > newError:
                    delta = i.item()
                    error = newError
            self.pitchDeltas = torch.cat([self.pitchDeltas, torch.tensor([delta])])
            batchStart += delta
        nBatches = self.pitchDeltas.size()[0]
        self.pitchBorders = torch.zeros(nBatches + 1, dtype = int)
        for i in range(nBatches):
            self.pitchBorders[i+1] = self.pitchBorders[i] + self.pitchDeltas[i]
        self.Pitch = torch.mean(self.pitchDeltas.float()).int()
        del batchSize
        del lowerSearchLimit
        del batchStart
        del sample
        del zeroTransitions
        del error
        del delta
        del shiftedSample
        del newError
        del nBatches
        
    def CalculateSpectra(self, iterations = 10, filterWidth = 10):
        Window = torch.hann_window(self.Pitch * 3)
        signals = torch.stft(self.waveform, self.Pitch * 3, hop_length = self.Pitch, win_length = self.Pitch * 3, window = Window, return_complex = True)
        signals = torch.transpose(signals, 0, 1)
        signals = signals.abs()
        workingSpectra = torch.log(signals)
        workingSpectra = torch.max(workingSpectra, torch.tensor([-100]))
        self.spectra = torch.full_like(workingSpectra, -float("inf"), dtype=torch.float)
        for i in range(iterations):
            workingSpectra = torch.max(workingSpectra, self.spectra)
            self.spectra = workingSpectra
            for i in range(filterWidth):
                self.spectra = torch.roll(workingSpectra, -i, dims = 1) + self.spectra + torch.roll(workingSpectra, i, dims = 1)
            self.spectra = self.spectra / (2 * filterWidth + 1)
        self.spectrum = torch.mean(self.spectra, 0)
        for i in range(self.spectra.size()[0]):
            self.spectra[i] = self.spectra[i] - self.spectrum
        del Window
        del signals
        del workingSpectra
        
    def CalculateExcitation(self):
        Window = torch.hann_window(self.Pitch * 3)
        signals = torch.stft(self.waveform, self.Pitch * 3, hop_length = self.Pitch, win_length = self.Pitch * 3, window = Window, return_complex = True)
        signals = torch.transpose(signals, 0, 1)
        excitations = torch.empty_like(signals)
        for i in range(excitations.size()[0]):
            excitations[i] = signals[i] / (torch.exp(self.spectrum) + torch.exp(self.spectra[i]))
        excitations = torch.transpose(excitations, 0, 1)
        self.excitation = torch.istft(excitations, self.Pitch * 3, hop_length = self.Pitch, win_length = self.Pitch * 3, window = Window, onesided = True)
        del Window
        del signals
        del excitations

# %%
class Synthesizer:
    def __init__(self, Excitation, Spectrum, Spectra, SampleRate):
        self.excitation = Excitation
        self.spectrum = Spectrum
        self.spectra = Spectra
        self.sampleRate = SampleRate
        self.returnSignal = torch.tensor([], dtype = float)
        
    def Synthesize(self, pitch, steadiness):
        Window = torch.hann_window(pitch * 3)
        self.returnSignal = torch.stft(self.excitation, pitch * 3, hop_length = pitch, win_length = pitch * 3, window = Window, return_complex = True)
        self.returnSignal = torch.transpose(self.returnSignal, 0, 1)
        for i in range(self.spectra.size()[0]):
            self.returnSignal[i] = self.returnSignal[i] * (torch.exp(self.spectrum) + math.pow(1 - steadiness, 2) * torch.roll(torch.exp(self.spectra), 0, dims=0)[i])
        self.returnSignal = torch.transpose(self.returnSignal, 0, 1)
        self.returnSignal = torch.istft(self.returnSignal, pitch * 3, hop_length = pitch, win_length = pitch * 3, window = Window, onesided=True, )
        del Window
        
    def save(self, filepath):
        torchaudio.save(filepath, torch.unsqueeze(self.returnSignal, 0), self.sampleRate, format="wav", encoding="PCM_S", bits_per_sample=32)

# %%
class RelLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(RelLoss, self).__init__()
 
    def forward(self, inputs, targets):    
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        differences = torch.abs(inputs - targets)
        sums = torch.abs(inputs + targets)
        out = (differences / sums).sum() / inputs.size()[0]
        return out

# %%
class SpecCrfAi(nn.Module):
    def __init__(self, learningRate=1e-5):
        super(SpecCrfAi, self).__init__()
        
        self.layer1 = torch.nn.Conv2d(1, 10, (51, 3), padding = (25, 0), bias = False)
        self.ReLu1 = nn.ReLU()
        self.layer2 = torch.nn.Conv2d(10, 10, (51, 1), padding = (25, 0), bias = False)
        self.ReLu2 = nn.ReLU()
        self.layer3 = torch.nn.Conv2d(10, 10, (51, 1), padding = (25, 0), bias = False)
        self.ReLu3 = nn.ReLU()
        self.layer4 = torch.nn.Conv2d(10, 1, (51, 1), padding = (25, 0), bias = False)
        
        self.learningRate = learningRate
        self.optimizer = torch.optim.Adam(self.parameters(), lr=self.learningRate, weight_decay=0.)
        #self.criterion = nn.L1Loss()
        self.criterion = RelLoss()
        
    def forward(self, spectrum1, spectrum2, factor):
        fac = torch.full((spectrum1.size()[0], 1), factor)
        x = torch.cat((spectrum1.unsqueeze(1), fac, spectrum2.unsqueeze(1)), dim = 1)
        x = x.float().unsqueeze(0).unsqueeze(0)
        x = self.layer1(x)
        x = self.ReLu1(x)
        x = self.layer2(x)
        x = self.ReLu2(x)
        x = self.layer3(x)
        x = self.ReLu3(x)
        x = self.layer4(x)
        return x
    
    def processData(self, spectrum1, spectrum2, factor):
        output = torch.squeeze(self(spectrum1, spectrum2, factor))
        return output
    
    def train(self, indata, epochs=1):
        for epoch in range(epochs):
            for data in self.dataLoader(indata):
                spectrum1 = data[0]
                spectrum2 = data[-1]
                indexList = numpy.arange(0, data.size()[0], 1)
                numpy.random.shuffle(indexList)
                for i in indexList:
                    factor = i / float(data.size()[0])
                    spectrumTarget = data[i]
                    output = torch.squeeze(self(spectrum1, spectrum2, factor))
                    loss = self.criterion(output, spectrumTarget)
                    self.optimizer.zero_grad()
                    loss.backward()
                    self.optimizer.step()
            print('epoch [{}/{}], loss:{:.4f}'
                  .format(epoch + 1, epochs, loss.data))
            
    def dataLoader(self, data):
        return torch.utils.data.DataLoader(dataset=data, shuffle=True)

# %%
class Synthesizer2:
    def __init__(self, SampleRate):
        self.sampleRate = SampleRate
        self.returnSignal = torch.tensor([], dtype = float)
        
    def Synthesize(self, steadiness, Spectrum, SpectraElement, Excitation):
        #Window = torch.hann_window(pitch * 3)
        modSpectrum = torch.exp(Spectrum) + math.pow(1 - steadiness, 2) * torch.roll(torch.exp(SpectraElement), 0, dims=0)
        modSpectrum = torch.cat((modSpectrum, torch.flip(modSpectrum, [0])[1:-1]), dim = 0)
        #print(Excitation.size())
        #print(modSpectrum.size())
        result = torch.fft.fft(Excitation) * modSpectrum
        result = torch.fft.ifft(result)
        return result
        
    def SynthesizeBatch(self, steadiness, Spectrum, Spectra, Excitation):
        poles = [0]
        waveforms = []
        self.returnSignal = torch.zeros_like(Excitation)
        for i in range(len(Spectra) - 1):
            delta = (Spectra[i].size()[0] * 2 - 1) / 3
            poles.append(poles[i] + delta)
            if 2 * poles[i] - poles[i+1] < 0.:
                ExcitationSegment = torch.cat((Excitation[int(2 * poles[i] - poles[i+1]):-1], Excitation[0:int(2 * poles[i+1] - poles[i])]), dim=0)#corr
            elif 2 * poles[i+1] - poles[i] > Excitation.size()[0]:
                ExcitationSegment = torch.cat((Excitation[int(2 * poles[i] - poles[i+1]):-1], Excitation[0:int(2 * poles[i+1] - poles[i] - Excitation.size()[0] + 1)]), dim=0)#corr
            else:
                ExcitationSegment = Excitation[int(2 * poles[i] - poles[i+1]):int(2 * poles[i+1] - poles[i] - 1)]
            result = self.Synthesize(steadiness, Spectrum[i], Spectra[i], ExcitationSegment)
            waveforms.append(result)
        
        for i in range(len(Spectra) - 1):
            pole1 = int((poles[i] + poles[i-1]) / 2)
            pole2 = int((poles[i+1] + poles[i]) / 2)
            if i < len(Spectra) - 2:
                pole3 = int((poles[i+2] + poles[i+1]) / 2)
            waveformStart = int(2 * poles[i] - poles[i+1])
            waveformEnd = int(2 * poles[i+1] - poles[i])
            if i == 0:
                waveforms[i][0:int(poles[i]-waveformStart)] = 0.
            elif waveformStart > pole1:
                for x in range(waveformStart, pole2):
                    AscSlope = math.pow(math.sin((x-waveformStart) * 0.5 * math.pi / (pole2-waveformStart)), 2)
                    waveforms[i][x-waveformStart] = waveforms[i][x-waveformStart] * AscSlope
            elif 2 * poles[i] - poles[i-1] < pole2:
                waveforms[i][0:pole1-waveformStart] = 0.
                for x in range(pole1, 2 * poles[i] - poles[i-1]):
                    AscSlope = math.pow(math.sin((x-pole1) * 0.5 * math.pi / (2 * poles[i] - poles[i-1]-pole1)), 2)
                    waveforms[i][x-waveformStart] = waveforms[i][x-pole1] * AscSlope
            else:
                waveforms[i][0:pole1-waveformStart] = 0.
                for x in range(pole1, pole2):
                    AscSlope = math.pow(math.sin((x-pole1) * 0.5 * math.pi / (pole2-pole1)), 2)
                    waveforms[i][x-waveformStart] = waveforms[i][x-waveformStart] * AscSlope
            if i == len(Spectra) - 2:
                waveforms[i][int(poles[i+1]-waveformStart):-1] = 0.
            elif waveformEnd < pole3:
                for x in range(pole2, waveformEnd):
                    DescSlope = math.pow(math.cos((x-pole2) * 0.5 * math.pi / (waveformEnd-pole2)), 2)
                    waveforms[i][x-waveformStart] = waveforms[i][x-waveformStart] * DescSlope
            elif 2 * poles[i+1] - poles[i+2] > pole2:
                waveforms[i][pole3-waveformEnd:-1] = 0.
                for x in range(pole2, pole3):
                    DescSlope = math.pow(math.cos((x - 2 * poles[i+1] + poles[i+2]) * 0.5 * math.pi / (pole3 - 2 * poles[i+1] + poles[i+2])), 2)
                    waveforms[i][x-waveformStart] = waveforms[i][x-waveformStart] * DescSlope
            else:
                waveforms[i][pole3-waveformEnd:-1] = 0.
                for x in range(pole2, pole3):
                    DescSlope = math.pow(math.cos((x-pole2) * 0.5 * math.pi / (pole3-pole2)), 2)
                    waveforms[i][x-waveformStart] = waveforms[i][x-waveformStart] * DescSlope
            if waveformStart < 0:
                self.returnSignal[0:waveformEnd] = self.returnSignal[0:waveformEnd] + waveforms[i][-1-waveformEnd:-1]#corr
            elif waveformEnd > self.returnSignal.size()[0]:
                self.returnSignal[waveformStart:-1] = self.returnSignal[waveformStart:-1] + waveforms[i][0:self.returnSignal.size()[0] - waveformStart]#corr
            else:
                self.returnSignal[waveformStart + 1:waveformEnd] = self.returnSignal[waveformStart + 1:waveformEnd] + waveforms[i]
            
            
    def save(self, filepath):
        torchaudio.save(filepath, torch.unsqueeze(self.returnSignal, 0).detach(), self.sampleRate, format="wav", encoding="PCM_S", bits_per_sample=32)

# %%
PhonemeSamples = dict([])
PhonemeKeys = ["A", "E", "I", "O", "U", "G", "K", "N", "S", "T"]

for key in PhonemeKeys:
    PhonemeSamples[key] = AudioSample("Samples_rip/"+key+".wav")
    PhonemeSamples[key].CalculatePitch(252.)
    PhonemeSamples[key].Pitch = 385
    PhonemeSamples[key].CalculateSpectra(iterations = 25)
    PhonemeSamples[key].CalculateExcitation()

TrainingSamples = dict([])
TrainingKeys = ["A_E", "A_G", "A_I", "A_K", "A_N", "A_O", "A_S", "A_T", "A_U",
                   "E_A", "E_G", "E_I", "E_K", "E_N", "E_O", "E_S", "E_T", "E_U",
                   "I_A", "I_E", "I_G", "I_K", "I_N", "I_O", "I_S", "I_T", "I_U",
                   "O_A", "O_E", "O_G", "O_I", "O_K", "O_N", "O_S", "O_T", "O_U",
                   "U_A", "U_E", "U_G", "U_I", "U_K", "U_N", "U_O", "U_S", "U_T",
                   "G_A", "G_E", "G_I", "G_O", "G_U",
                   "K_A", "K_E", "K_I", "K_O", "K_U",
                   "N_A", "N_E", "N_I", "N_O", "N_U",
                   "S_A", "S_E", "S_I", "S_O", "S_U",
                   "T_A", "T_E", "T_I", "T_O", "T_U"
                  ]

for key in TrainingKeys:
    TrainingSamples[key] = AudioSample("Samples_rip/"+key+".wav")
    TrainingSamples[key].CalculatePitch(252.)
    TrainingSamples[key].CalculateSpectra(iterations = 25)
    TrainingSamples[key].CalculateExcitation()

# %%
trainSpectra = []
i = 0
for key in TrainingKeys:
    trainSpectra.append(torch.empty_like(TrainingSamples[key].spectra))
    for j in range(TrainingSamples[key].spectra.size()[0]):
        trainSpectra[i][j] = TrainingSamples[key].spectrum + TrainingSamples[key].spectra[j]
    i += 1
    
specCrfAi = SpecCrfAi()
for i in range(70):
    specCrfAi.train(trainSpectra[i], epochs = 50)
# Out:
# epoch [1/50], loss:0.9099
# epoch [2/50], loss:0.8925
# epoch [3/50], loss:0.9734
# epoch [4/50], loss:0.9222
# epoch [5/50], loss:0.9137
# epoch [6/50], loss:1.0568
# epoch [7/50], loss:0.8770
# epoch [8/50], loss:0.8823
# epoch [9/50], loss:0.8891
# epoch [10/50], loss:0.8878
# epoch [11/50], loss:1.0196
# epoch [12/50], loss:0.8791
# epoch [13/50], loss:1.0166
# epoch [14/50], loss:0.8588
# epoch [15/50], loss:0.8801
# epoch [16/50], loss:0.9748
# epoch [17/50], loss:0.8515
# epoch [18/50], loss:0.8367
# epoch [19/50], loss:0.8254
# epoch [20/50], loss:1.1676
# epoch [21/50], loss:0.9295
# epoch [22/50], loss:0.8015
# epoch [23/50], loss:0.8276
# epoch [24/50], loss:0.8876
# epoch [25/50], loss:0.8279
# epoch [26/50], loss:0.7943
# epoch [27/50], loss:0.8469
# epoch [28/50], loss:0.9168
# epoch [29/50], loss:0.7919
# epoch [30/50], loss:0.7682
# epoch [31/50], loss:0.7855
# epoch [32/50], loss:0.7371
# epoch [33/50], loss:0.7604
# epoch [34/50], loss:0.8768
# epoch [35/50], loss:0.7980
# epoch [36/50], loss:0.9828
# epoch [37/50], loss:0.7260
# epoch [38/50], loss:0.7116
# epoch [39/50], loss:0.6961
# epoch [40/50], loss:0.7498
# epoch [41/50], loss:0.6825
# epoch [42/50], loss:0.6933
# epoch [43/50], loss:0.6694
# epoch [44/50], loss:0.6509
# epoch [45/50], loss:0.6579
# epoch [46/50], loss:0.6449
# epoch [47/50], loss:0.6212
# epoch [48/50], loss:0.6110
# epoch [49/50], loss:0.6114
# epoch [50/50], loss:0.5788
# epoch [1/50], loss:0.4796
# epoch [2/50], loss:0.3868
# epoch [3/50], loss:0.3884
# epoch [4/50], loss:0.4072
# epoch [5/50], loss:0.4065
# epoch [6/50], loss:0.3625
# epoch [7/50], loss:0.4193
# epoch [8/50], loss:0.3550
# epoch [9/50], loss:0.6463
# epoch [10/50], loss:0.3714
# epoch [11/50], loss:0.3825
# epoch [12/50], loss:0.3344
# epoch [13/50], loss:0.3981
# epoch [14/50], loss:0.3625
# epoch [15/50], loss:0.3646
# epoch [16/50], loss:0.3653
# epoch [17/50], loss:0.3944
# epoch [18/50], loss:0.3136
# epoch [19/50], loss:0.4114
# epoch [20/50], loss:0.3514
# epoch [21/50], loss:0.3462
# epoch [22/50], loss:0.2986
# epoch [23/50], loss:0.2971
# epoch [24/50], loss:0.4108
# epoch [25/50], loss:0.3361
# epoch [26/50], loss:0.3342
# epoch [27/50], loss:0.3485
# epoch [28/50], loss:0.3224
# epoch [29/50], loss:0.3172
# epoch [30/50], loss:0.2742
# epoch [31/50], loss:0.3328
# epoch [32/50], loss:0.2651
# epoch [33/50], loss:0.3110
# epoch [34/50], loss:0.3041
# epoch [35/50], loss:0.3040
# epoch [36/50], loss:0.3022
# epoch [37/50], loss:0.2469
# epoch [38/50], loss:0.2437
# epoch [39/50], loss:0.2432
# epoch [40/50], loss:0.2360
# epoch [41/50], loss:0.2838
# epoch [42/50], loss:0.2379
# epoch [43/50], loss:0.4369
# epoch [44/50], loss:0.2762
# epoch [45/50], loss:0.2238
# epoch [46/50], loss:0.2160
# epoch [47/50], loss:0.2119
# epoch [48/50], loss:0.2498
# epoch [49/50], loss:0.2730
# epoch [50/50], loss:0.3659
# epoch [1/50], loss:0.3417
# epoch [2/50], loss:0.3719
# epoch [3/50], loss:0.3264
# epoch [4/50], loss:0.3445
# epoch [5/50], loss:0.3377
# epoch [6/50], loss:0.3567
# epoch [7/50], loss:0.3562
# epoch [8/50], loss:0.3986
# epoch [9/50], loss:0.3183
# epoch [10/50], loss:0.3158
# epoch [11/50], loss:0.3149
# epoch [12/50], loss:0.3647
# epoch [13/50], loss:0.3249
# epoch [14/50], loss:0.3435
# epoch [15/50], loss:0.3057
# epoch [16/50], loss:0.3756
# epoch [17/50], loss:0.3374
# epoch [18/50], loss:0.2967
# epoch [19/50], loss:0.3238
# epoch [20/50], loss:0.3861
# epoch [21/50], loss:0.3080
# epoch [22/50], loss:0.3695
# epoch [23/50], loss:0.3234
# epoch [24/50], loss:0.3380
# epoch [25/50], loss:0.3200
# epoch [26/50], loss:0.3704
# epoch [27/50], loss:0.3712
# epoch [28/50], loss:0.2968
# epoch [29/50], loss:0.2738
# epoch [30/50], loss:0.3226
# epoch [31/50], loss:0.3033
# epoch [32/50], loss:0.2980
# epoch [33/50], loss:0.3039
# epoch [34/50], loss:0.3028
# epoch [35/50], loss:0.2676
# epoch [36/50], loss:0.2985
# epoch [37/50], loss:0.3055
# epoch [38/50], loss:0.3479
# epoch [39/50], loss:0.2593
# epoch [40/50], loss:0.2415
# epoch [41/50], loss:0.3045
# epoch [42/50], loss:0.2550
# epoch [43/50], loss:0.2566
# epoch [44/50], loss:0.2482
# epoch [45/50], loss:0.2557
# epoch [46/50], loss:0.5405
# epoch [47/50], loss:0.3201
# epoch [48/50], loss:0.2774
# epoch [49/50], loss:0.2367
# epoch [50/50], loss:0.2767
# epoch [1/50], loss:0.4128
# epoch [2/50], loss:0.3035
# epoch [3/50], loss:0.2103
# epoch [4/50], loss:0.2082
# epoch [5/50], loss:0.2086
# epoch [6/50], loss:0.3334
# epoch [7/50], loss:0.3332
# epoch [8/50], loss:0.3485
# epoch [9/50], loss:0.2468
# epoch [10/50], loss:0.2375
# epoch [11/50], loss:0.2390
# epoch [12/50], loss:0.2855
# epoch [13/50], loss:0.2456
# epoch [14/50], loss:0.2444
# epoch [15/50], loss:0.3514
# epoch [16/50], loss:0.2300
# epoch [17/50], loss:0.3175
# epoch [18/50], loss:0.1889
# epoch [19/50], loss:0.1893
# epoch [20/50], loss:0.2623
# epoch [21/50], loss:0.2428
# epoch [22/50], loss:0.2249
# epoch [23/50], loss:0.2236
# epoch [24/50], loss:0.2807
# epoch [25/50], loss:0.2559
# epoch [26/50], loss:0.1777
# epoch [27/50], loss:0.2681
# epoch [28/50], loss:0.2493
# epoch [29/50], loss:0.2890
# epoch [30/50], loss:0.2093
# epoch [31/50], loss:0.3288
# epoch [32/50], loss:0.2215
# epoch [33/50], loss:0.2088
# epoch [34/50], loss:0.2263
# epoch [35/50], loss:0.1494
# epoch [36/50], loss:0.2414
# epoch [37/50], loss:0.1415
# epoch [38/50], loss:0.1384
# epoch [39/50], loss:0.2518
# epoch [40/50], loss:0.1291
# epoch [41/50], loss:0.2477
# epoch [42/50], loss:0.2860
# epoch [43/50], loss:0.1691
# epoch [44/50], loss:0.0353
# epoch [45/50], loss:0.0817
# epoch [46/50], loss:0.0815
# epoch [47/50], loss:0.0423
# epoch [48/50], loss:0.1447
# epoch [49/50], loss:0.0483
# epoch [50/50], loss:0.0753
# epoch [1/50], loss:0.1544
# epoch [2/50], loss:0.0724
# epoch [3/50], loss:0.2338
# epoch [4/50], loss:0.2188
# epoch [5/50], loss:0.0909
# epoch [6/50], loss:0.1219
# epoch [7/50], loss:0.0757
# epoch [8/50], loss:0.1821
# epoch [9/50], loss:0.1819
# epoch [10/50], loss:0.0896
# epoch [11/50], loss:0.0687
# epoch [12/50], loss:0.0700
# epoch [13/50], loss:0.1193
# epoch [14/50], loss:0.3350
# epoch [15/50], loss:0.1520
# epoch [16/50], loss:0.2164
# epoch [17/50], loss:0.0952
# epoch [18/50], loss:0.2306
# epoch [19/50], loss:0.0807
# epoch [20/50], loss:0.2918
# epoch [21/50], loss:0.1123
# epoch [22/50], loss:0.1845
# epoch [23/50], loss:0.2545
# epoch [24/50], loss:0.2187
# epoch [25/50], loss:0.2199
# epoch [26/50], loss:0.2757
# epoch [27/50], loss:0.2136
# epoch [28/50], loss:0.8106
# epoch [29/50], loss:0.2923
# epoch [30/50], loss:0.3229
# epoch [31/50], loss:0.1827
# epoch [32/50], loss:0.2603
# epoch [33/50], loss:0.1284
# epoch [34/50], loss:0.0901
# epoch [35/50], loss:0.8185
# epoch [36/50], loss:0.2275
# epoch [37/50], loss:0.0896
# epoch [38/50], loss:0.0895
# epoch [39/50], loss:0.1599
# epoch [40/50], loss:0.2682
# epoch [41/50], loss:0.3193
# epoch [42/50], loss:0.1071
# epoch [43/50], loss:0.4113
# epoch [44/50], loss:0.4251
# epoch [45/50], loss:0.3708
# epoch [46/50], loss:0.2218
# epoch [47/50], loss:0.2739
# epoch [48/50], loss:0.1109
# epoch [49/50], loss:0.3196
# epoch [50/50], loss:0.4267
# epoch [1/50], loss:0.2360
# epoch [2/50], loss:0.0793
# epoch [3/50], loss:0.0788
# epoch [4/50], loss:0.0851
# epoch [5/50], loss:0.0983
# epoch [6/50], loss:0.0812
# epoch [7/50], loss:0.0945
# epoch [8/50], loss:0.0826
# epoch [9/50], loss:0.0938
# epoch [10/50], loss:0.1369
# epoch [11/50], loss:0.0898
# epoch [12/50], loss:0.0898
# epoch [13/50], loss:0.0767
# epoch [14/50], loss:0.0933
# epoch [15/50], loss:0.0836
# epoch [16/50], loss:0.0883
# epoch [17/50], loss:0.0758
# epoch [18/50], loss:0.0832
# epoch [19/50], loss:0.1363
# epoch [20/50], loss:0.1328
# epoch [21/50], loss:0.0865
# epoch [22/50], loss:0.0829
# epoch [23/50], loss:0.0817
# epoch [24/50], loss:0.0770
# epoch [25/50], loss:0.0924
# epoch [26/50], loss:0.1334
# epoch [27/50], loss:0.0954
# epoch [28/50], loss:0.0931
# epoch [29/50], loss:0.2151
# epoch [30/50], loss:0.0870
# epoch [31/50], loss:0.0968
# epoch [32/50], loss:0.0778
# epoch [33/50], loss:0.0798
# epoch [34/50], loss:0.0745
# epoch [35/50], loss:0.0744
# epoch [36/50], loss:0.0919
# epoch [37/50], loss:0.0864
# epoch [38/50], loss:0.1241
# epoch [39/50], loss:0.1276
# epoch [40/50], loss:0.1812
# epoch [41/50], loss:0.0735
# epoch [42/50], loss:0.0860
# epoch [43/50], loss:0.0734
# epoch [44/50], loss:0.1784
# epoch [45/50], loss:0.2073
# epoch [46/50], loss:0.0780
# epoch [47/50], loss:0.0749
# epoch [48/50], loss:0.1320
# epoch [49/50], loss:0.0882
# epoch [50/50], loss:0.0787
# epoch [1/50], loss:0.4093
# epoch [2/50], loss:0.2266
# epoch [3/50], loss:0.3825
# epoch [4/50], loss:0.1393
# epoch [5/50], loss:0.2459
# epoch [6/50], loss:0.2562
# epoch [7/50], loss:0.1262
# epoch [8/50], loss:0.1312
# epoch [9/50], loss:0.1290
# epoch [10/50], loss:0.1066
# epoch [11/50], loss:0.1236
# epoch [12/50], loss:0.3040
# epoch [13/50], loss:0.2230
# epoch [14/50], loss:0.1367
# epoch [15/50], loss:0.2109
# epoch [16/50], loss:0.1903
# epoch [17/50], loss:0.1432
# epoch [18/50], loss:0.2510
# epoch [19/50], loss:0.1644
# epoch [20/50], loss:0.1617
# epoch [21/50], loss:0.1621
# epoch [22/50], loss:0.1666
# epoch [23/50], loss:0.1637
# epoch [24/50], loss:0.1783
# epoch [25/50], loss:0.8173
# epoch [26/50], loss:0.2610
# epoch [27/50], loss:0.1596
# epoch [28/50], loss:0.1747
# epoch [29/50], loss:0.1590
# epoch [30/50], loss:0.3433
# epoch [31/50], loss:0.2758
# epoch [32/50], loss:0.1478
# epoch [33/50], loss:0.1586
# epoch [34/50], loss:0.1533
# epoch [35/50], loss:0.1732
# epoch [36/50], loss:0.1321
# epoch [37/50], loss:0.1764
# epoch [38/50], loss:0.2493
# epoch [39/50], loss:0.1332
# epoch [40/50], loss:0.1689
# epoch [41/50], loss:0.1446
# epoch [42/50], loss:0.1444
# epoch [43/50], loss:0.1956
# epoch [44/50], loss:0.1536
# epoch [45/50], loss:0.3907
# epoch [46/50], loss:0.1505
# epoch [47/50], loss:0.2381
# epoch [48/50], loss:0.1279
# epoch [49/50], loss:0.1656
# epoch [50/50], loss:0.2002
# epoch [1/50], loss:0.0756
# epoch [2/50], loss:0.0768
# epoch [3/50], loss:0.1562
# epoch [4/50], loss:0.0743
# epoch [5/50], loss:0.0729
# epoch [6/50], loss:0.1426
# epoch [7/50], loss:0.0692
# epoch [8/50], loss:0.1611
# epoch [9/50], loss:0.0669
# epoch [10/50], loss:0.0659
# epoch [11/50], loss:0.1126
# epoch [12/50], loss:0.1268
# epoch [13/50], loss:0.2315
# epoch [14/50], loss:0.1617
# epoch [15/50], loss:0.1469
# epoch [16/50], loss:0.1482
# epoch [17/50], loss:0.1456
# epoch [18/50], loss:0.3435
# epoch [19/50], loss:0.1581
# epoch [20/50], loss:0.1437
# epoch [21/50], loss:0.1306
# epoch [22/50], loss:0.1416
# epoch [23/50], loss:0.0538
# epoch [24/50], loss:0.1939
# epoch [25/50], loss:0.1491
# epoch [26/50], loss:0.2101
# epoch [27/50], loss:0.1389
# epoch [28/50], loss:0.0447
# epoch [29/50], loss:0.1233
# epoch [30/50], loss:0.1217
# epoch [31/50], loss:0.1219
# epoch [32/50], loss:0.1429
# epoch [33/50], loss:0.1210
# epoch [34/50], loss:0.0450
# epoch [35/50], loss:0.1217
# epoch [36/50], loss:0.1223
# epoch [37/50], loss:0.0445
# epoch [38/50], loss:0.1211
# epoch [39/50], loss:0.0424
# epoch [40/50], loss:0.1720
# epoch [41/50], loss:0.0431
# epoch [42/50], loss:0.1197
# epoch [43/50], loss:0.1569
# epoch [44/50], loss:0.1365
# epoch [45/50], loss:0.1640
# epoch [46/50], loss:0.2307
# epoch [47/50], loss:0.0441
# epoch [48/50], loss:0.0459
# epoch [49/50], loss:0.1190
# epoch [50/50], loss:0.0445
# epoch [1/50], loss:0.1116
# epoch [2/50], loss:0.1189
# epoch [3/50], loss:0.1284
# epoch [4/50], loss:0.1122
# epoch [5/50], loss:0.1947
# epoch [6/50], loss:0.1497
# epoch [7/50], loss:0.1046
# epoch [8/50], loss:0.0944
# epoch [9/50], loss:0.1203
# epoch [10/50], loss:0.0942
# epoch [11/50], loss:0.0942
# epoch [12/50], loss:0.1251
# epoch [13/50], loss:0.1098
# epoch [14/50], loss:0.1164
# epoch [15/50], loss:0.1344
# epoch [16/50], loss:0.0991
# epoch [17/50], loss:0.1083
# epoch [18/50], loss:0.1082
# epoch [19/50], loss:0.1289
# epoch [20/50], loss:0.1501
# epoch [21/50], loss:0.1337
# epoch [22/50], loss:0.1178
# epoch [23/50], loss:0.1164
# epoch [24/50], loss:0.0984
# epoch [25/50], loss:0.1337
# epoch [26/50], loss:0.1705
# epoch [27/50], loss:0.1187
# epoch [28/50], loss:0.1193
# epoch [29/50], loss:0.1283
# epoch [30/50], loss:0.2003
# epoch [31/50], loss:0.1120
# epoch [32/50], loss:0.1407
# epoch [33/50], loss:0.1096
# epoch [34/50], loss:0.1035
# epoch [35/50], loss:0.1675
# epoch [36/50], loss:0.1437
# epoch [37/50], loss:0.1225
# epoch [38/50], loss:0.1319
# epoch [39/50], loss:0.1172
# epoch [40/50], loss:0.1224
# epoch [41/50], loss:0.1143
# epoch [42/50], loss:0.0965
# epoch [43/50], loss:0.1152
# epoch [44/50], loss:0.1145
# epoch [45/50], loss:0.1139
# epoch [46/50], loss:0.1149
# epoch [47/50], loss:0.1225
# epoch [48/50], loss:0.1029
# epoch [49/50], loss:0.1134
# epoch [50/50], loss:0.1076
# epoch [1/50], loss:0.1241
# epoch [2/50], loss:0.1152
# epoch [3/50], loss:0.1077
# epoch [4/50], loss:0.3914
# epoch [5/50], loss:0.1068
# epoch [6/50], loss:0.1078
# epoch [7/50], loss:0.1244
# epoch [8/50], loss:0.1119
# epoch [9/50], loss:0.2060
# epoch [10/50], loss:0.0991
# epoch [11/50], loss:0.1222
# epoch [12/50], loss:0.1167
# epoch [13/50], loss:0.1794
# epoch [14/50], loss:0.1064
# epoch [15/50], loss:0.1584
# epoch [16/50], loss:0.1284
# epoch [17/50], loss:0.1270
# epoch [18/50], loss:0.1004
# epoch [19/50], loss:0.1572
# epoch [20/50], loss:0.1075
# epoch [21/50], loss:0.1007
# epoch [22/50], loss:0.0972
# epoch [23/50], loss:0.1850
# epoch [24/50], loss:0.1579
# epoch [25/50], loss:0.1259
# epoch [26/50], loss:0.1034
# epoch [27/50], loss:0.0984
# epoch [28/50], loss:0.1660
# epoch [29/50], loss:0.1338
# epoch [30/50], loss:0.1750
# epoch [31/50], loss:0.1865
# epoch [32/50], loss:0.1192
# epoch [33/50], loss:0.1201
# epoch [34/50], loss:0.0960
# epoch [35/50], loss:0.0994
# epoch [36/50], loss:0.1248
# epoch [37/50], loss:0.1350
# epoch [38/50], loss:0.1025
# epoch [39/50], loss:0.1452
# epoch [40/50], loss:0.1099
# epoch [41/50], loss:0.1324
# epoch [42/50], loss:0.0949
# epoch [43/50], loss:0.1211
# epoch [44/50], loss:0.1324
# epoch [45/50], loss:0.1017
# epoch [46/50], loss:0.0956
# epoch [47/50], loss:0.0973
# epoch [48/50], loss:0.1442
# epoch [49/50], loss:0.0943
# epoch [50/50], loss:0.0969
# epoch [1/50], loss:0.1202
# epoch [2/50], loss:0.1116
# epoch [3/50], loss:0.4362
# epoch [4/50], loss:0.3305
# epoch [5/50], loss:0.0970
# epoch [6/50], loss:0.0936
# epoch [7/50], loss:0.4271
# epoch [8/50], loss:0.1896
# epoch [9/50], loss:0.1149
# epoch [10/50], loss:0.2948
# epoch [11/50], loss:0.1503
# epoch [12/50], loss:0.3448
# epoch [13/50], loss:0.2006
# epoch [14/50], loss:0.1675
# epoch [15/50], loss:0.0704
# epoch [16/50], loss:0.0687
# epoch [17/50], loss:0.1629
# epoch [18/50], loss:0.1462
# epoch [19/50], loss:0.0656
# epoch [20/50], loss:0.4825
# epoch [21/50], loss:0.4103
# epoch [22/50], loss:0.1431
# epoch [23/50], loss:0.1706
# epoch [24/50], loss:0.1601
# epoch [25/50], loss:0.0596
# epoch [26/50], loss:0.0583
# epoch [27/50], loss:0.2597
# epoch [28/50], loss:0.2608
# epoch [29/50], loss:0.2196
# epoch [30/50], loss:0.2599
# epoch [31/50], loss:0.0600
# epoch [32/50], loss:0.4683
# epoch [33/50], loss:0.2244
# epoch [34/50], loss:0.0613
# epoch [35/50], loss:0.0614
# epoch [36/50], loss:0.2992
# epoch [37/50], loss:0.3302
# epoch [38/50], loss:0.2901
# epoch [39/50], loss:0.1342
# epoch [40/50], loss:0.1221
# epoch [41/50], loss:0.1575
# epoch [42/50], loss:0.0900
# epoch [43/50], loss:0.3125
# epoch [44/50], loss:0.2264
# epoch [45/50], loss:0.0587
# epoch [46/50], loss:0.1555
# epoch [47/50], loss:0.0579
# epoch [48/50], loss:0.2773
# epoch [49/50], loss:0.3276
# epoch [50/50], loss:0.0559
# epoch [1/50], loss:0.3389
# epoch [2/50], loss:0.3743
# epoch [3/50], loss:13.2228
# epoch [4/50], loss:0.1477
# epoch [5/50], loss:0.2797
# epoch [6/50], loss:0.1265
# epoch [7/50], loss:0.1212
# epoch [8/50], loss:0.2510
# epoch [9/50], loss:0.1244
# epoch [10/50], loss:0.2858
# epoch [11/50], loss:0.3037
# epoch [12/50], loss:0.1185
# epoch [13/50], loss:0.2377
# epoch [14/50], loss:0.1217
# epoch [15/50], loss:0.3033
# epoch [16/50], loss:0.1228
# epoch [17/50], loss:0.1169
# epoch [18/50], loss:0.2991
# epoch [19/50], loss:0.1709
# epoch [20/50], loss:0.2441
# epoch [21/50], loss:0.1219
# epoch [22/50], loss:0.1273
# epoch [23/50], loss:0.1250
# epoch [24/50], loss:0.1158
# epoch [25/50], loss:0.1212
# epoch [26/50], loss:0.2368
# epoch [27/50], loss:0.2587
# epoch [28/50], loss:0.2485
# epoch [29/50], loss:0.4851
# epoch [30/50], loss:0.2799
# epoch [31/50], loss:0.1125
# epoch [32/50], loss:0.1163
# epoch [33/50], loss:0.3363
# epoch [34/50], loss:0.1993
# epoch [35/50], loss:0.1342
# epoch [36/50], loss:0.1184
# epoch [37/50], loss:0.1209
# epoch [38/50], loss:0.2378
# epoch [39/50], loss:0.5162
# epoch [40/50], loss:0.7217
# epoch [41/50], loss:0.1996
# epoch [42/50], loss:0.2374
# epoch [43/50], loss:0.3043
# epoch [44/50], loss:0.3529
# epoch [45/50], loss:0.1180
# epoch [46/50], loss:0.1402
# epoch [47/50], loss:0.1153
# epoch [48/50], loss:0.1064
# epoch [49/50], loss:0.3176
# epoch [50/50], loss:0.1969
# epoch [1/50], loss:0.1966
# epoch [2/50], loss:0.5923
# epoch [3/50], loss:0.2437
# epoch [4/50], loss:0.2524
# epoch [5/50], loss:0.0639
# epoch [6/50], loss:0.2087
# epoch [7/50], loss:0.2041
# epoch [8/50], loss:0.1676
# epoch [9/50], loss:0.2280
# epoch [10/50], loss:0.2077
# epoch [11/50], loss:0.0608
# epoch [12/50], loss:0.2035
# epoch [13/50], loss:0.0600
# epoch [14/50], loss:0.0607
# epoch [15/50], loss:0.0626
# epoch [16/50], loss:0.3891
# epoch [17/50], loss:0.1899
# epoch [18/50], loss:0.1865
# epoch [19/50], loss:0.1824
# epoch [20/50], loss:0.1827
# epoch [21/50], loss:0.2936
# epoch [22/50], loss:0.2441
# epoch [23/50], loss:0.0555
# epoch [24/50], loss:0.0580
# epoch [25/50], loss:0.1616
# epoch [26/50], loss:0.0559
# epoch [27/50], loss:0.0587
# epoch [28/50], loss:0.2229
# epoch [29/50], loss:0.2167
# epoch [30/50], loss:0.2343
# epoch [31/50], loss:0.1203
# epoch [32/50], loss:0.0536
# epoch [33/50], loss:0.2009
# epoch [34/50], loss:0.2100
# epoch [35/50], loss:0.2098
# epoch [36/50], loss:0.0528
# epoch [37/50], loss:0.2170
# epoch [38/50], loss:0.0510
# epoch [39/50], loss:0.0517
# epoch [40/50], loss:0.1877
# epoch [41/50], loss:0.0501
# epoch [42/50], loss:0.0507
# epoch [43/50], loss:0.1797
# epoch [44/50], loss:0.0514
# epoch [45/50], loss:0.2011
# epoch [46/50], loss:0.0508
# epoch [47/50], loss:0.1991
# epoch [48/50], loss:0.0480
# epoch [49/50], loss:0.3473
# epoch [50/50], loss:0.2498
# epoch [1/50], loss:0.1500
# epoch [2/50], loss:0.1447
# epoch [3/50], loss:0.2039
# epoch [4/50], loss:0.2121
# epoch [5/50], loss:0.2458
# epoch [6/50], loss:0.1854
# epoch [7/50], loss:0.5040
# epoch [8/50], loss:0.1482
# epoch [9/50], loss:0.1489
# epoch [10/50], loss:0.2006
# epoch [11/50], loss:0.2003
# epoch [12/50], loss:0.1282
# epoch [13/50], loss:0.2020
# epoch [14/50], loss:0.1999
# epoch [15/50], loss:0.1555
# epoch [16/50], loss:0.1474
# epoch [17/50], loss:0.1278
# epoch [18/50], loss:0.1241
# epoch [19/50], loss:0.1565
# epoch [20/50], loss:0.1558
# epoch [21/50], loss:0.2112
# epoch [22/50], loss:0.1276
# epoch [23/50], loss:0.1496
# epoch [24/50], loss:0.1578
# epoch [25/50], loss:0.1047
# epoch [26/50], loss:0.1561
# epoch [27/50], loss:0.1513
# epoch [28/50], loss:0.1448
# epoch [29/50], loss:0.1317
# epoch [30/50], loss:0.1493
# epoch [31/50], loss:0.1448
# epoch [32/50], loss:0.1242
# epoch [33/50], loss:0.1416
# epoch [34/50], loss:0.2469
# epoch [35/50], loss:0.1415
# epoch [36/50], loss:0.1516
# epoch [37/50], loss:0.1042
# epoch [38/50], loss:0.4527
# epoch [39/50], loss:0.1270
# epoch [40/50], loss:0.1318
# epoch [41/50], loss:0.2478
# epoch [42/50], loss:0.1348
# epoch [43/50], loss:0.1505
# epoch [44/50], loss:0.2112
# epoch [45/50], loss:0.1360
# epoch [46/50], loss:0.2475
# epoch [47/50], loss:0.1245
# epoch [48/50], loss:0.1487
# epoch [49/50], loss:0.1245
# epoch [50/50], loss:0.2138
# epoch [1/50], loss:0.7395
# epoch [2/50], loss:0.3088
# epoch [3/50], loss:0.1284
# epoch [4/50], loss:0.1852
# epoch [5/50], loss:0.0945
# epoch [6/50], loss:0.0925
# epoch [7/50], loss:0.1507
# epoch [8/50], loss:0.3444
# epoch [9/50], loss:0.5975
# epoch [10/50], loss:0.1255
# epoch [11/50], loss:0.1664
# epoch [12/50], loss:0.1326
# epoch [13/50], loss:0.1381
# epoch [14/50], loss:0.3057
# epoch [15/50], loss:0.1011
# epoch [16/50], loss:0.0832
# epoch [17/50], loss:0.3487
# epoch [18/50], loss:0.1362
# epoch [19/50], loss:0.1184
# epoch [20/50], loss:1.1299
# epoch [21/50], loss:1.1239
# epoch [22/50], loss:0.1007
# epoch [23/50], loss:0.0828
# epoch [24/50], loss:0.1054
# epoch [25/50], loss:0.2283
# epoch [26/50], loss:0.1377
# epoch [27/50], loss:0.1482
# epoch [28/50], loss:0.1613
# epoch [29/50], loss:0.1677
# epoch [30/50], loss:0.5983
# epoch [31/50], loss:0.1038
# epoch [32/50], loss:0.3372
# epoch [33/50], loss:0.0996
# epoch [34/50], loss:0.1765
# epoch [35/50], loss:0.1415
# epoch [36/50], loss:0.1502
# epoch [37/50], loss:0.1320
# epoch [38/50], loss:0.1541
# epoch [39/50], loss:0.1248
# epoch [40/50], loss:0.1757
# epoch [41/50], loss:0.2218
# epoch [42/50], loss:0.0746
# epoch [43/50], loss:0.1178
# epoch [44/50], loss:0.1771
# epoch [45/50], loss:0.2643
# epoch [46/50], loss:0.1352
# epoch [47/50], loss:0.1193
# epoch [48/50], loss:0.1325
# epoch [49/50], loss:0.1315
# epoch [50/50], loss:0.1192
# epoch [1/50], loss:0.3829
# epoch [2/50], loss:0.2022
# epoch [3/50], loss:0.3329
# epoch [4/50], loss:0.1875
# epoch [5/50], loss:0.2101
# epoch [6/50], loss:0.1757
# epoch [7/50], loss:0.1834
# epoch [8/50], loss:0.1581
# epoch [9/50], loss:0.1428
# epoch [10/50], loss:0.2469
# epoch [11/50], loss:0.2004
# epoch [12/50], loss:0.1752
# epoch [13/50], loss:0.1752
# epoch [14/50], loss:0.2102
# epoch [15/50], loss:0.2464
# epoch [16/50], loss:0.1752
# epoch [17/50], loss:0.2200
# epoch [18/50], loss:0.2199
# epoch [19/50], loss:0.2977
# epoch [20/50], loss:0.1869
# epoch [21/50], loss:0.2397
# epoch [22/50], loss:0.2553
# epoch [23/50], loss:0.1749
# epoch [24/50], loss:0.3507
# epoch [25/50], loss:0.2457
# epoch [26/50], loss:0.2001
# epoch [27/50], loss:0.1834
# epoch [28/50], loss:0.2550
# epoch [29/50], loss:0.1350
# epoch [30/50], loss:0.2662
# epoch [31/50], loss:0.1398
# epoch [32/50], loss:0.6036
# epoch [33/50], loss:0.1573
# epoch [34/50], loss:0.5693
# epoch [35/50], loss:0.1743
# epoch [36/50], loss:0.2454
# epoch [37/50], loss:0.1702
# epoch [38/50], loss:0.1703
# epoch [39/50], loss:0.1176
# epoch [40/50], loss:0.2946
# epoch [41/50], loss:0.1343
# epoch [42/50], loss:0.1699
# epoch [43/50], loss:0.1394
# epoch [44/50], loss:0.1824
# epoch [45/50], loss:0.2078
# epoch [46/50], loss:0.2196
# epoch [47/50], loss:0.1658
# epoch [48/50], loss:0.3393
# epoch [49/50], loss:0.1817
# epoch [50/50], loss:0.5869
# epoch [1/50], loss:0.0709
# epoch [2/50], loss:0.0717
# epoch [3/50], loss:0.0706
# epoch [4/50], loss:0.1916
# epoch [5/50], loss:0.1604
# epoch [6/50], loss:0.1378
# epoch [7/50], loss:0.0683
# epoch [8/50], loss:0.0668
# epoch [9/50], loss:0.0682
# epoch [10/50], loss:0.0966
# epoch [11/50], loss:0.1179
# epoch [12/50], loss:0.0963
# epoch [13/50], loss:0.1414
# epoch [14/50], loss:0.1167
# epoch [15/50], loss:0.0557
# epoch [16/50], loss:0.0660
# epoch [17/50], loss:0.0639
# epoch [18/50], loss:0.1299
# epoch [19/50], loss:0.1868
# epoch [20/50], loss:0.0651
# epoch [21/50], loss:0.1803
# epoch [22/50], loss:0.1669
# epoch [23/50], loss:0.0683
# epoch [24/50], loss:0.1074
# epoch [25/50], loss:0.1100
# epoch [26/50], loss:0.1088
# epoch [27/50], loss:0.1198
# epoch [28/50], loss:0.1161
# epoch [29/50], loss:0.1385
# epoch [30/50], loss:0.0598
# epoch [31/50], loss:0.0939
# epoch [32/50], loss:0.0591
# epoch [33/50], loss:0.0588
# epoch [34/50], loss:0.1518
# epoch [35/50], loss:0.1383
# epoch [36/50], loss:0.0603
# epoch [37/50], loss:0.0579
# epoch [38/50], loss:0.0601
# epoch [39/50], loss:0.0566
# epoch [40/50], loss:0.0529
# epoch [41/50], loss:0.0566
# epoch [42/50], loss:0.1085
# epoch [43/50], loss:0.1130
# epoch [44/50], loss:0.0554
# epoch [45/50], loss:0.0923
# epoch [46/50], loss:0.1042
# epoch [47/50], loss:0.0550
# epoch [48/50], loss:0.1173
# epoch [49/50], loss:0.0542
# epoch [50/50], loss:0.0916
# epoch [1/50], loss:0.1496
# epoch [2/50], loss:0.1948
# epoch [3/50], loss:0.1909
# epoch [4/50], loss:0.0945
# epoch [5/50], loss:0.1099
# epoch [6/50], loss:3.3422
# epoch [7/50], loss:0.3240
# epoch [8/50], loss:0.4856
# epoch [9/50], loss:0.1972
# epoch [10/50], loss:0.4321
# epoch [11/50], loss:0.1913
# epoch [12/50], loss:0.1213
# epoch [13/50], loss:0.2301
# epoch [14/50], loss:0.3301
# epoch [15/50], loss:0.1287
# epoch [16/50], loss:0.2356
# epoch [17/50], loss:0.3981
# epoch [18/50], loss:0.5361
# epoch [19/50], loss:0.1486
# epoch [20/50], loss:0.7414
# epoch [21/50], loss:0.6909
# epoch [22/50], loss:0.2226
# epoch [23/50], loss:0.3624
# epoch [24/50], loss:0.6595
# epoch [25/50], loss:0.1345
# epoch [26/50], loss:0.2183
# epoch [27/50], loss:0.1455
# epoch [28/50], loss:0.7292
# epoch [29/50], loss:0.3920
# epoch [30/50], loss:0.2395
# epoch [31/50], loss:0.1339
# epoch [32/50], loss:0.1468
# epoch [33/50], loss:0.5890
# epoch [34/50], loss:0.5283
# epoch [35/50], loss:0.1102
# epoch [36/50], loss:0.1361
# epoch [37/50], loss:0.1191
# epoch [38/50], loss:0.3952
# epoch [39/50], loss:0.1020
# epoch [40/50], loss:0.1294
# epoch [41/50], loss:0.1136
# epoch [42/50], loss:0.5766
# epoch [43/50], loss:0.4153
# epoch [44/50], loss:0.1103
# epoch [45/50], loss:0.6723
# epoch [46/50], loss:0.3756
# epoch [47/50], loss:0.3514
# epoch [48/50], loss:0.4032
# epoch [49/50], loss:0.1507
# epoch [50/50], loss:0.1305
# epoch [1/50], loss:0.1262
# epoch [2/50], loss:0.2152
# epoch [3/50], loss:0.1023
# epoch [4/50], loss:0.1479
# epoch [5/50], loss:0.1459
# epoch [6/50], loss:0.1085
# epoch [7/50], loss:0.1229
# epoch [8/50], loss:0.1585
# epoch [9/50], loss:0.1180
# epoch [10/50], loss:0.1618
# epoch [11/50], loss:0.1173
# epoch [12/50], loss:0.2444
# epoch [13/50], loss:0.1007
# epoch [14/50], loss:0.1750
# epoch [15/50], loss:0.1609
# epoch [16/50], loss:0.1750
# epoch [17/50], loss:0.1344
# epoch [18/50], loss:0.1749
# epoch [19/50], loss:0.1580
# epoch [20/50], loss:0.1453
# epoch [21/50], loss:0.1163
# epoch [22/50], loss:0.1337
# epoch [23/50], loss:0.2184
# epoch [24/50], loss:0.1433
# epoch [25/50], loss:0.1737
# epoch [26/50], loss:0.2223
# epoch [27/50], loss:0.1352
# epoch [28/50], loss:0.1202
# epoch [29/50], loss:0.1153
# epoch [30/50], loss:0.1504
# epoch [31/50], loss:0.1194
# epoch [32/50], loss:0.1149
# epoch [33/50], loss:0.1201
# epoch [34/50], loss:0.1528
# epoch [35/50], loss:0.1147
# epoch [36/50], loss:0.1257
# epoch [37/50], loss:0.1331
# epoch [38/50], loss:0.1315
# epoch [39/50], loss:0.1257
# epoch [40/50], loss:0.1148
# epoch [41/50], loss:0.2273
# epoch [42/50], loss:0.1252
# epoch [43/50], loss:0.2086
# epoch [44/50], loss:0.1141
# epoch [45/50], loss:0.1313
# epoch [46/50], loss:0.1247
# epoch [47/50], loss:0.1044
# epoch [48/50], loss:0.1701
# epoch [49/50], loss:0.1420
# epoch [50/50], loss:0.1371
# epoch [1/50], loss:0.2655
# epoch [2/50], loss:0.6794
# epoch [3/50], loss:0.1883
# epoch [4/50], loss:0.2307
# epoch [5/50], loss:0.1855
# epoch [6/50], loss:0.2307
# epoch [7/50], loss:0.3449
# epoch [8/50], loss:0.2350
# epoch [9/50], loss:0.4050
# epoch [10/50], loss:0.4236
# epoch [11/50], loss:0.2245
# epoch [12/50], loss:0.3964
# epoch [13/50], loss:0.2996
# epoch [14/50], loss:0.4166
# epoch [15/50], loss:0.2509
# epoch [16/50], loss:0.2347
# epoch [17/50], loss:0.2994
# epoch [18/50], loss:0.2989
# epoch [19/50], loss:0.2256
# epoch [20/50], loss:0.6371
# epoch [21/50], loss:0.1847
# epoch [22/50], loss:0.1877
# epoch [23/50], loss:0.2445
# epoch [24/50], loss:0.4321
# epoch [25/50], loss:0.2465
# epoch [26/50], loss:0.6622
# epoch [27/50], loss:0.2257
# epoch [28/50], loss:0.1875
# epoch [29/50], loss:0.6614
# epoch [30/50], loss:0.4172
# epoch [31/50], loss:0.2097
# epoch [32/50], loss:0.3072
# epoch [33/50], loss:0.2264
# epoch [34/50], loss:0.3244
# epoch [35/50], loss:0.2644
# epoch [36/50], loss:0.2441
# epoch [37/50], loss:0.5593
# epoch [38/50], loss:0.2978
# epoch [39/50], loss:1.0527
# epoch [40/50], loss:0.5542
# epoch [41/50], loss:0.3439
# epoch [42/50], loss:0.1986
# epoch [43/50], loss:0.2246
# epoch [44/50], loss:0.2538
# epoch [45/50], loss:0.3971
# epoch [46/50], loss:0.2640
# epoch [47/50], loss:0.2639
# epoch [48/50], loss:0.6549
# epoch [49/50], loss:0.2457
# epoch [50/50], loss:0.3367
# epoch [1/50], loss:0.1897
# epoch [2/50], loss:0.1219
# epoch [3/50], loss:0.1287
# epoch [4/50], loss:0.1164
# epoch [5/50], loss:0.2278
# epoch [6/50], loss:0.0620
# epoch [7/50], loss:0.0665
# epoch [8/50], loss:0.0576
# epoch [9/50], loss:0.0654
# epoch [10/50], loss:0.2438
# epoch [11/50], loss:0.0639
# epoch [12/50], loss:0.2088
# epoch [13/50], loss:0.2440
# epoch [14/50], loss:0.3372
# epoch [15/50], loss:0.2371
# epoch [16/50], loss:0.0573
# epoch [17/50], loss:0.0543
# epoch [18/50], loss:0.0671
# epoch [19/50], loss:0.0605
# epoch [20/50], loss:0.2834
# epoch [21/50], loss:0.0558
# epoch [22/50], loss:0.1962
# epoch [23/50], loss:0.0539
# epoch [24/50], loss:0.3679
# epoch [25/50], loss:0.0488
# epoch [26/50], loss:0.2118
# epoch [27/50], loss:0.2281
# epoch [28/50], loss:0.0515
# epoch [29/50], loss:0.2362
# epoch [30/50], loss:0.2341
# epoch [31/50], loss:0.1976
# epoch [32/50], loss:0.0537
# epoch [33/50], loss:0.2065
# epoch [34/50], loss:0.0480
# epoch [35/50], loss:0.3365
# epoch [36/50], loss:0.0515
# epoch [37/50], loss:0.0775
# epoch [38/50], loss:0.0413
# epoch [39/50], loss:0.0416
# epoch [40/50], loss:0.2691
# epoch [41/50], loss:0.0410
# epoch [42/50], loss:0.0455
# epoch [43/50], loss:0.2310
# epoch [44/50], loss:0.0418
# epoch [45/50], loss:0.0459
# epoch [46/50], loss:0.2302
# epoch [47/50], loss:0.2064
# epoch [48/50], loss:0.4340
# epoch [49/50], loss:0.0434
# epoch [50/50], loss:0.1998
# epoch [1/50], loss:0.0404
# epoch [2/50], loss:0.2023
# epoch [3/50], loss:0.0411
# epoch [4/50], loss:0.0405
# epoch [5/50], loss:0.0372
# epoch [6/50], loss:0.0386
# epoch [7/50], loss:0.2552
# epoch [8/50], loss:0.0381
# epoch [9/50], loss:0.2049
# epoch [10/50], loss:0.2448
# epoch [11/50], loss:0.2610
# epoch [12/50], loss:0.0342
# epoch [13/50], loss:0.0344
# epoch [14/50], loss:0.0362
# epoch [15/50], loss:0.0370
# epoch [16/50], loss:0.0454
# epoch [17/50], loss:0.0346
# epoch [18/50], loss:0.1800
# epoch [19/50], loss:0.1819
# epoch [20/50], loss:0.0342
# epoch [21/50], loss:0.0366
# epoch [22/50], loss:0.0360
# epoch [23/50], loss:0.1801
# epoch [24/50], loss:0.1802
# epoch [25/50], loss:0.0346
# epoch [26/50], loss:0.1910
# epoch [27/50], loss:0.1800
# epoch [28/50], loss:0.0375
# epoch [29/50], loss:0.0380
# epoch [30/50], loss:0.1797
# epoch [31/50], loss:0.0338
# epoch [32/50], loss:0.0338
# epoch [33/50], loss:0.1850
# epoch [34/50], loss:0.0360
# epoch [35/50], loss:0.0361
# epoch [36/50], loss:0.1468
# epoch [37/50], loss:0.1467
# epoch [38/50], loss:0.2468
# epoch [39/50], loss:0.1725
# epoch [40/50], loss:0.1758
# epoch [41/50], loss:0.0338
# epoch [42/50], loss:0.2999
# epoch [43/50], loss:0.0359
# epoch [44/50], loss:0.2150
# epoch [45/50], loss:0.1408
# epoch [46/50], loss:0.1774
# epoch [47/50], loss:0.0357
# epoch [48/50], loss:0.0369
# epoch [49/50], loss:0.1457
# epoch [50/50], loss:0.0370
# epoch [1/50], loss:0.1801
# epoch [2/50], loss:0.3551
# epoch [3/50], loss:0.1685
# epoch [4/50], loss:0.2015
# epoch [5/50], loss:0.2660
# epoch [6/50], loss:0.2114
# epoch [7/50], loss:0.1933
# epoch [8/50], loss:0.1718
# epoch [9/50], loss:0.1846
# epoch [10/50], loss:0.1697
# epoch [11/50], loss:0.1746
# epoch [12/50], loss:0.1665
# epoch [13/50], loss:0.2190
# epoch [14/50], loss:0.2225
# epoch [15/50], loss:0.2141
# epoch [16/50], loss:0.2161
# epoch [17/50], loss:0.2124
# epoch [18/50], loss:0.1697
# epoch [19/50], loss:0.2767
# epoch [20/50], loss:0.1617
# epoch [21/50], loss:0.1644
# epoch [22/50], loss:0.1954
# epoch [23/50], loss:0.2732
# epoch [24/50], loss:0.2147
# epoch [25/50], loss:0.1821
# epoch [26/50], loss:0.1586
# epoch [27/50], loss:0.2358
# epoch [28/50], loss:0.2471
# epoch [29/50], loss:0.1816
# epoch [30/50], loss:0.1946
# epoch [31/50], loss:0.1685
# epoch [32/50], loss:0.1815
# epoch [33/50], loss:0.1943
# epoch [34/50], loss:0.2130
# epoch [35/50], loss:0.1944
# epoch [36/50], loss:0.1927
# epoch [37/50], loss:0.1632
# epoch [38/50], loss:0.1576
# epoch [39/50], loss:0.2005
# epoch [40/50], loss:0.1973
# epoch [41/50], loss:0.2117
# epoch [42/50], loss:0.1559
# epoch [43/50], loss:0.1478
# epoch [44/50], loss:0.2171
# epoch [45/50], loss:0.1796
# epoch [46/50], loss:0.2194
# epoch [47/50], loss:0.1996
# epoch [48/50], loss:0.2161
# epoch [49/50], loss:0.1835
# epoch [50/50], loss:0.2107
# epoch [1/50], loss:1.1161
# epoch [2/50], loss:0.3787
# epoch [3/50], loss:0.4888
# epoch [4/50], loss:1.7357
# epoch [5/50], loss:0.7684
# epoch [6/50], loss:0.5383
# epoch [7/50], loss:1.3060
# epoch [8/50], loss:0.5899
# epoch [9/50], loss:0.7621
# epoch [10/50], loss:0.6697
# epoch [11/50], loss:0.7542
# epoch [12/50], loss:0.6518
# epoch [13/50], loss:0.6189
# epoch [14/50], loss:1.7404
# epoch [15/50], loss:0.7490
# epoch [16/50], loss:1.2780
# epoch [17/50], loss:0.6735
# epoch [18/50], loss:0.7925
# epoch [19/50], loss:0.5995
# epoch [20/50], loss:1.3535
# epoch [21/50], loss:0.6177
# epoch [22/50], loss:0.7405
# epoch [23/50], loss:0.6631
# epoch [24/50], loss:0.8824
# epoch [25/50], loss:0.6411
# epoch [26/50], loss:0.6434
# epoch [27/50], loss:0.6479
# epoch [28/50], loss:0.6607
# epoch [29/50], loss:0.6401
# epoch [30/50], loss:0.8782
# epoch [31/50], loss:0.6392
# epoch [32/50], loss:0.6637
# epoch [33/50], loss:1.2350
# epoch [34/50], loss:0.6394
# epoch [35/50], loss:0.9522
# epoch [36/50], loss:0.6412
# epoch [37/50], loss:0.6847
# epoch [38/50], loss:0.7724
# epoch [39/50], loss:0.8687
# epoch [40/50], loss:0.5900
# epoch [41/50], loss:0.6531
# epoch [42/50], loss:0.6809
# epoch [43/50], loss:0.6805
# epoch [44/50], loss:0.6783
# epoch [45/50], loss:0.6789
# epoch [46/50], loss:0.6298
# epoch [47/50], loss:0.6359
# epoch [48/50], loss:0.7012
# epoch [49/50], loss:0.6363
# epoch [50/50], loss:0.6359
# epoch [1/50], loss:0.9765
# epoch [2/50], loss:1.0516
# epoch [3/50], loss:1.0394
# epoch [4/50], loss:0.8977
# epoch [5/50], loss:0.8716
# epoch [6/50], loss:1.5663
# epoch [7/50], loss:1.0428
# epoch [8/50], loss:0.9714
# epoch [9/50], loss:0.7990
# epoch [10/50], loss:1.1689
# epoch [11/50], loss:0.7927
# epoch [12/50], loss:1.1371
# epoch [13/50], loss:0.7855
# epoch [14/50], loss:1.3594
# epoch [15/50], loss:1.0415
# epoch [16/50], loss:1.1991
# epoch [17/50], loss:0.6118
# epoch [18/50], loss:1.1822
# epoch [19/50], loss:0.9698
# epoch [20/50], loss:1.1472
# epoch [21/50], loss:0.6088
# epoch [22/50], loss:1.3592
# epoch [23/50], loss:1.1662
# epoch [24/50], loss:1.6966
# epoch [25/50], loss:0.7332
# epoch [26/50], loss:1.0477
# epoch [27/50], loss:1.2188
# epoch [28/50], loss:1.6473
# epoch [29/50], loss:0.7903
# epoch [30/50], loss:1.0399
# epoch [31/50], loss:1.6953
# epoch [32/50], loss:1.1801
# epoch [33/50], loss:1.7001
# epoch [34/50], loss:1.1344
# epoch [35/50], loss:1.1343
# epoch [36/50], loss:1.6766
# epoch [37/50], loss:1.8358
# epoch [38/50], loss:1.0985
# epoch [39/50], loss:1.6955
# epoch [40/50], loss:0.5758
# epoch [41/50], loss:1.2053
# epoch [42/50], loss:1.8300
# epoch [43/50], loss:1.2943
# epoch [44/50], loss:1.1788
# epoch [45/50], loss:1.0405
# epoch [46/50], loss:1.1785
# epoch [47/50], loss:1.1636
# epoch [48/50], loss:0.9649
# epoch [49/50], loss:0.7511
# epoch [50/50], loss:1.6852
# epoch [1/50], loss:0.7929
# epoch [2/50], loss:0.3133
# epoch [3/50], loss:0.3164
# epoch [4/50], loss:0.7887
# epoch [5/50], loss:0.9364
# epoch [6/50], loss:0.3132
# epoch [7/50], loss:0.3157
# epoch [8/50], loss:0.7632
# epoch [9/50], loss:0.7480
# epoch [10/50], loss:0.3174
# epoch [11/50], loss:0.3132
# epoch [12/50], loss:0.3140
# epoch [13/50], loss:1.1766
# epoch [14/50], loss:0.7403
# epoch [15/50], loss:1.5934
# epoch [16/50], loss:0.3294
# epoch [17/50], loss:1.8321
# epoch [18/50], loss:0.3134
# epoch [19/50], loss:0.7476
# epoch [20/50], loss:0.3166
# epoch [21/50], loss:1.0911
# epoch [22/50], loss:0.8327
# epoch [23/50], loss:0.8331
# epoch [24/50], loss:0.3479
# epoch [25/50], loss:0.7748
# epoch [26/50], loss:0.6757
# epoch [27/50], loss:0.3472
# epoch [28/50], loss:1.4602
# epoch [29/50], loss:0.3100
# epoch [30/50], loss:0.7350
# epoch [31/50], loss:0.3092
# epoch [32/50], loss:0.3093
# epoch [33/50], loss:1.1607
# epoch [34/50], loss:0.3102
# epoch [35/50], loss:0.7438
# epoch [36/50], loss:1.2103
# epoch [37/50], loss:0.7430
# epoch [38/50], loss:0.3096
# epoch [39/50], loss:0.8662
# epoch [40/50], loss:0.7577
# epoch [41/50], loss:0.3080
# epoch [42/50], loss:0.7380
# epoch [43/50], loss:0.8751
# epoch [44/50], loss:0.9490
# epoch [45/50], loss:0.3043
# epoch [46/50], loss:0.3040
# epoch [47/50], loss:0.8249
# epoch [48/50], loss:0.7339
# epoch [49/50], loss:0.3032
# epoch [50/50], loss:0.3031
# epoch [1/50], loss:1.2887
# epoch [2/50], loss:1.0049
# epoch [3/50], loss:0.9115
# epoch [4/50], loss:0.8953
# epoch [5/50], loss:2.5200
# epoch [6/50], loss:0.8577
# epoch [7/50], loss:1.0954
# epoch [8/50], loss:1.2020
# epoch [9/50], loss:0.8903
# epoch [10/50], loss:1.2385
# epoch [11/50], loss:0.8900
# epoch [12/50], loss:0.9258
# epoch [13/50], loss:1.0937
# epoch [14/50], loss:0.9806
# epoch [15/50], loss:1.0934
# epoch [16/50], loss:0.9414
# epoch [17/50], loss:1.0028
# epoch [18/50], loss:0.9960
# epoch [19/50], loss:1.2562
# epoch [20/50], loss:2.9347
# epoch [21/50], loss:0.8670
# epoch [22/50], loss:1.1932
# epoch [23/50], loss:0.9076
# epoch [24/50], loss:2.6492
# epoch [25/50], loss:1.0119
# epoch [26/50], loss:1.9552
# epoch [27/50], loss:1.0067
# epoch [28/50], loss:0.8869
# epoch [29/50], loss:1.4621
# epoch [30/50], loss:1.2793
# epoch [31/50], loss:1.5659
# epoch [32/50], loss:1.0336
# epoch [33/50], loss:1.0303
# epoch [34/50], loss:1.2574
# epoch [35/50], loss:1.5491
# epoch [36/50], loss:1.2721
# epoch [37/50], loss:1.1660
# epoch [38/50], loss:2.5470
# epoch [39/50], loss:2.0827
# epoch [40/50], loss:1.7003
# epoch [41/50], loss:2.4912
# epoch [42/50], loss:2.7370
# epoch [43/50], loss:2.0705
# epoch [44/50], loss:2.2238
# epoch [45/50], loss:13.5495
# epoch [46/50], loss:1.5105
# epoch [47/50], loss:1.5818
# epoch [48/50], loss:4.2563
# epoch [49/50], loss:5.6978
# epoch [50/50], loss:1.5577
# epoch [1/50], loss:1.5387
# epoch [2/50], loss:1.5061
# epoch [3/50], loss:2.9699
# epoch [4/50], loss:1.5092
# epoch [5/50], loss:1.2546
# epoch [6/50], loss:1.7271
# epoch [7/50], loss:1.8024
# epoch [8/50], loss:1.7287
# epoch [9/50], loss:1.5572
# epoch [10/50], loss:5.2476
# epoch [11/50], loss:1.3090
# epoch [12/50], loss:1.8003
# epoch [13/50], loss:1.6379
# epoch [14/50], loss:1.3090
# epoch [15/50], loss:1.3250
# epoch [16/50], loss:2.6365
# epoch [17/50], loss:5.0572
# epoch [18/50], loss:2.1764
# epoch [19/50], loss:1.6493
# epoch [20/50], loss:2.6256
# epoch [21/50], loss:1.6210
# epoch [22/50], loss:1.5078
# epoch [23/50], loss:3.7869
# epoch [24/50], loss:1.5217
# epoch [25/50], loss:1.6615
# epoch [26/50], loss:3.8183
# epoch [27/50], loss:1.6362
# epoch [28/50], loss:3.1531
# epoch [29/50], loss:3.8727
# epoch [30/50], loss:1.6474
# epoch [31/50], loss:1.5212
# epoch [32/50], loss:1.5596
# epoch [33/50], loss:1.5204
# epoch [34/50], loss:1.7138
# epoch [35/50], loss:1.5952
# epoch [36/50], loss:1.7471
# epoch [37/50], loss:1.2515
# epoch [38/50], loss:2.2986
# epoch [39/50], loss:3.4930
# epoch [40/50], loss:1.6330
# epoch [41/50], loss:1.5272
# epoch [42/50], loss:1.6327
# epoch [43/50], loss:3.2030
# epoch [44/50], loss:1.6615
# epoch [45/50], loss:1.2483
# epoch [46/50], loss:1.6318
# epoch [47/50], loss:2.3458
# epoch [48/50], loss:1.7613
# epoch [49/50], loss:1.2480
# epoch [50/50], loss:2.1543
# epoch [1/50], loss:2.3444
# epoch [2/50], loss:10.0285
# epoch [3/50], loss:2.2376
# epoch [4/50], loss:2.0016
# epoch [5/50], loss:2.0077
# epoch [6/50], loss:2.3919
# epoch [7/50], loss:1.8571
# epoch [8/50], loss:2.0958
# epoch [9/50], loss:2.2262
# epoch [10/50], loss:2.4504
# epoch [11/50], loss:2.7137
# epoch [12/50], loss:4.2072
# epoch [13/50], loss:4.2726
# epoch [14/50], loss:2.1421
# epoch [15/50], loss:1.8772
# epoch [16/50], loss:1.7716
# epoch [17/50], loss:2.3218
# epoch [18/50], loss:3.7558
# epoch [19/50], loss:2.9669
# epoch [20/50], loss:1.8569
# epoch [21/50], loss:4.0496
# epoch [22/50], loss:4.5491
# epoch [23/50], loss:1.9795
# epoch [24/50], loss:2.2802
# epoch [25/50], loss:1.6994
# epoch [26/50], loss:2.4155
# epoch [27/50], loss:6.4923
# epoch [28/50], loss:2.2726
# epoch [29/50], loss:3.5583
# epoch [30/50], loss:4.4696
# epoch [31/50], loss:4.5083
# epoch [32/50], loss:2.9312
# epoch [33/50], loss:1.9451
# epoch [34/50], loss:2.6267
# epoch [35/50], loss:2.1104
# epoch [36/50], loss:2.8323
# epoch [37/50], loss:3.9876
# epoch [38/50], loss:1.9510
# epoch [39/50], loss:2.4672
# epoch [40/50], loss:2.2105
# epoch [41/50], loss:5.1705
# epoch [42/50], loss:2.0994
# epoch [43/50], loss:2.2433
# epoch [44/50], loss:2.1065
# epoch [45/50], loss:3.6630
# epoch [46/50], loss:2.2216
# epoch [47/50], loss:3.2035
# epoch [48/50], loss:1.5482
# epoch [49/50], loss:2.3026
# epoch [50/50], loss:5.9388
# epoch [1/50], loss:0.9911
# epoch [2/50], loss:1.3760
# epoch [3/50], loss:1.7080
# epoch [4/50], loss:0.4764
# epoch [5/50], loss:1.6851
# epoch [6/50], loss:1.2884
# epoch [7/50], loss:0.4532
# epoch [8/50], loss:0.4527
# epoch [9/50], loss:2.0988
# epoch [10/50], loss:0.4401
# epoch [11/50], loss:0.4386
# epoch [12/50], loss:1.5406
# epoch [13/50], loss:1.6019
# epoch [14/50], loss:0.4191
# epoch [15/50], loss:0.4060
# epoch [16/50], loss:1.4308
# epoch [17/50], loss:0.3863
# epoch [18/50], loss:0.3169
# epoch [19/50], loss:0.3381
# epoch [20/50], loss:1.3378
# epoch [21/50], loss:0.3151
# epoch [22/50], loss:1.7939
# epoch [23/50], loss:0.3272
# epoch [24/50], loss:1.5088
# epoch [25/50], loss:1.5251
# epoch [26/50], loss:1.3094
# epoch [27/50], loss:0.7640
# epoch [28/50], loss:1.1508
# epoch [29/50], loss:1.2261
# epoch [30/50], loss:2.2557
# epoch [31/50], loss:0.7553
# epoch [32/50], loss:1.0327
# epoch [33/50], loss:1.1614
# epoch [34/50], loss:1.3999
# epoch [35/50], loss:1.4890
# epoch [36/50], loss:1.3122
# epoch [37/50], loss:1.2358
# epoch [38/50], loss:0.2680
# epoch [39/50], loss:0.2737
# epoch [40/50], loss:0.2614
# epoch [41/50], loss:1.1193
# epoch [42/50], loss:1.3771
# epoch [43/50], loss:0.2520
# epoch [44/50], loss:0.8061
# epoch [45/50], loss:0.2572
# epoch [46/50], loss:0.2424
# epoch [47/50], loss:0.2398
# epoch [48/50], loss:0.2368
# epoch [49/50], loss:0.7870
# epoch [50/50], loss:0.2309
# epoch [1/50], loss:1.0518
# epoch [2/50], loss:1.2126
# epoch [3/50], loss:1.0546
# epoch [4/50], loss:1.3162
# epoch [5/50], loss:4.3660
# epoch [6/50], loss:2.2105
# epoch [7/50], loss:1.1267
# epoch [8/50], loss:1.0714
# epoch [9/50], loss:1.2249
# epoch [10/50], loss:1.1265
# epoch [11/50], loss:1.0892
# epoch [12/50], loss:1.2084
# epoch [13/50], loss:1.2078
# epoch [14/50], loss:2.5301
# epoch [15/50], loss:1.3220
# epoch [16/50], loss:1.4729
# epoch [17/50], loss:1.1884
# epoch [18/50], loss:1.2739
# epoch [19/50], loss:1.1914
# epoch [20/50], loss:1.6622
# epoch [21/50], loss:1.2302
# epoch [22/50], loss:1.9458
# epoch [23/50], loss:1.1851
# epoch [24/50], loss:1.7965
# epoch [25/50], loss:1.2511
# epoch [26/50], loss:1.9348
# epoch [27/50], loss:1.1909
# epoch [28/50], loss:1.1821
# epoch [29/50], loss:1.1815
# epoch [30/50], loss:1.7717
# epoch [31/50], loss:1.2076
# epoch [32/50], loss:1.5154
# epoch [33/50], loss:1.3766
# epoch [34/50], loss:1.4341
# epoch [35/50], loss:1.1807
# epoch [36/50], loss:1.2412
# epoch [37/50], loss:1.4561
# epoch [38/50], loss:1.3933
# epoch [39/50], loss:1.2096
# epoch [40/50], loss:1.3612
# epoch [41/50], loss:1.3492
# epoch [42/50], loss:1.7075
# epoch [43/50], loss:1.2740
# epoch [44/50], loss:1.2862
# epoch [45/50], loss:1.4429
# epoch [46/50], loss:1.1693
# epoch [47/50], loss:1.1575
# epoch [48/50], loss:2.1989
# epoch [49/50], loss:1.2680
# epoch [50/50], loss:1.3741
# epoch [1/50], loss:0.8291
# epoch [2/50], loss:0.3756
# epoch [3/50], loss:0.3753
# epoch [4/50], loss:0.3725
# epoch [5/50], loss:0.3721
# epoch [6/50], loss:0.3724
# epoch [7/50], loss:1.0104
# epoch [8/50], loss:0.7937
# epoch [9/50], loss:0.8544
# epoch [10/50], loss:0.8509
# epoch [11/50], loss:2.4927
# epoch [12/50], loss:0.3672
# epoch [13/50], loss:0.3653
# epoch [14/50], loss:0.8680
# epoch [15/50], loss:0.8448
# epoch [16/50], loss:1.6362
# epoch [17/50], loss:0.8022
# epoch [18/50], loss:0.3607
# epoch [19/50], loss:0.8625
# epoch [20/50], loss:0.3566
# epoch [21/50], loss:0.7938
# epoch [22/50], loss:0.3945
# epoch [23/50], loss:0.9283
# epoch [24/50], loss:0.7946
# epoch [25/50], loss:0.8388
# epoch [26/50], loss:1.2736
# epoch [27/50], loss:2.1591
# epoch [28/50], loss:0.3463
# epoch [29/50], loss:0.8792
# epoch [30/50], loss:0.8782
# epoch [31/50], loss:1.4665
# epoch [32/50], loss:0.3418
# epoch [33/50], loss:0.3738
# epoch [34/50], loss:1.0034
# epoch [35/50], loss:0.3372
# epoch [36/50], loss:0.3347
# epoch [37/50], loss:2.0067
# epoch [38/50], loss:0.3451
# epoch [39/50], loss:1.4227
# epoch [40/50], loss:0.8182
# epoch [41/50], loss:0.3243
# epoch [42/50], loss:0.3279
# epoch [43/50], loss:0.4099
# epoch [44/50], loss:0.3533
# epoch [45/50], loss:0.3164
# epoch [46/50], loss:1.1846
# epoch [47/50], loss:0.7404
# epoch [48/50], loss:0.3090
# epoch [49/50], loss:0.7498
# epoch [50/50], loss:0.9401
# epoch [1/50], loss:2.2683
# epoch [2/50], loss:1.1672
# epoch [3/50], loss:1.2918
# epoch [4/50], loss:1.3129
# epoch [5/50], loss:1.3646
# epoch [6/50], loss:2.2408
# epoch [7/50], loss:0.5797
# epoch [8/50], loss:0.5959
# epoch [9/50], loss:1.1072
# epoch [10/50], loss:1.0396
# epoch [11/50], loss:1.3014
# epoch [12/50], loss:1.0352
# epoch [13/50], loss:1.0950
# epoch [14/50], loss:1.8904
# epoch [15/50], loss:2.5555
# epoch [16/50], loss:0.7347
# epoch [17/50], loss:1.0668
# epoch [18/50], loss:1.5131
# epoch [19/50], loss:1.3996
# epoch [20/50], loss:0.8995
# epoch [21/50], loss:0.6190
# epoch [22/50], loss:1.2658
# epoch [23/50], loss:1.5095
# epoch [24/50], loss:1.0064
# epoch [25/50], loss:1.0482
# epoch [26/50], loss:0.5310
# epoch [27/50], loss:1.0975
# epoch [28/50], loss:0.7122
# epoch [29/50], loss:0.9863
# epoch [30/50], loss:0.5867
# epoch [31/50], loss:2.6460
# epoch [32/50], loss:1.0914
# epoch [33/50], loss:0.9959
# epoch [34/50], loss:0.9775
# epoch [35/50], loss:1.2481
# epoch [36/50], loss:0.9658
# epoch [37/50], loss:0.9920
# epoch [38/50], loss:1.0603
# epoch [39/50], loss:1.0828
# epoch [40/50], loss:0.9740
# epoch [41/50], loss:1.0781
# epoch [42/50], loss:0.9738
# epoch [43/50], loss:1.2268
# epoch [44/50], loss:0.9677
# epoch [45/50], loss:1.2224
# epoch [46/50], loss:1.0323
# epoch [47/50], loss:1.0433
# epoch [48/50], loss:1.7573
# epoch [49/50], loss:1.0270
# epoch [50/50], loss:0.9577
# epoch [1/50], loss:1.0786
# epoch [2/50], loss:0.6660
# epoch [3/50], loss:1.5866
# epoch [4/50], loss:1.1040
# epoch [5/50], loss:1.7193
# epoch [6/50], loss:1.9208
# epoch [7/50], loss:1.8352
# epoch [8/50], loss:1.0659
# epoch [9/50], loss:2.6356
# epoch [10/50], loss:1.8945
# epoch [11/50], loss:1.6545
# epoch [12/50], loss:1.5395
# epoch [13/50], loss:1.7678
# epoch [14/50], loss:1.9264
# epoch [15/50], loss:1.1927
# epoch [16/50], loss:2.1773
# epoch [17/50], loss:2.0132
# epoch [18/50], loss:1.1841
# epoch [19/50], loss:0.9913
# epoch [20/50], loss:1.7520
# epoch [21/50], loss:1.1784
# epoch [22/50], loss:2.1462
# epoch [23/50], loss:1.3907
# epoch [24/50], loss:1.3889
# epoch [25/50], loss:1.8813
# epoch [26/50], loss:2.3154
# epoch [27/50], loss:1.8634
# epoch [28/50], loss:1.6966
# epoch [29/50], loss:1.6170
# epoch [30/50], loss:1.3134
# epoch [31/50], loss:1.7047
# epoch [32/50], loss:1.8548
# epoch [33/50], loss:1.7273
# epoch [34/50], loss:0.9865
# epoch [35/50], loss:2.6797
# epoch [36/50], loss:2.6517
# epoch [37/50], loss:0.9640
# epoch [38/50], loss:1.0073
# epoch [39/50], loss:0.9544
# epoch [40/50], loss:1.6373
# epoch [41/50], loss:1.0420
# epoch [42/50], loss:0.9550
# epoch [43/50], loss:2.5427
# epoch [44/50], loss:2.8545
# epoch [45/50], loss:2.5330
# epoch [46/50], loss:1.9629
# epoch [47/50], loss:1.6268
# epoch [48/50], loss:0.9909
# epoch [49/50], loss:2.2923
# epoch [50/50], loss:1.3481
# epoch [1/50], loss:0.6327
# epoch [2/50], loss:0.7386
# epoch [3/50], loss:1.6108
# epoch [4/50], loss:1.5458
# epoch [5/50], loss:2.4787
# epoch [6/50], loss:2.4059
# epoch [7/50], loss:0.6913
# epoch [8/50], loss:1.0801
# epoch [9/50], loss:2.4922
# epoch [10/50], loss:0.7379
# epoch [11/50], loss:1.5049
# epoch [12/50], loss:1.6431
# epoch [13/50], loss:1.2782
# epoch [14/50], loss:1.2638
# epoch [15/50], loss:0.7360
# epoch [16/50], loss:0.7089
# epoch [17/50], loss:1.5015
# epoch [18/50], loss:1.4877
# epoch [19/50], loss:4.9532
# epoch [20/50], loss:3.3141
# epoch [21/50], loss:2.1293
# epoch [22/50], loss:10.7855
# epoch [23/50], loss:3.7125
# epoch [24/50], loss:0.7227
# epoch [25/50], loss:1.4175
# epoch [26/50], loss:0.9896
# epoch [27/50], loss:2.8654
# epoch [28/50], loss:1.3671
# epoch [29/50], loss:1.6266
# epoch [30/50], loss:1.6394
# epoch [31/50], loss:0.6811
# epoch [32/50], loss:1.6417
# epoch [33/50], loss:0.7162
# epoch [34/50], loss:0.6971
# epoch [35/50], loss:0.6885
# epoch [36/50], loss:0.8502
# epoch [37/50], loss:1.4976
# epoch [38/50], loss:1.2639
# epoch [39/50], loss:1.4735
# epoch [40/50], loss:0.6558
# epoch [41/50], loss:0.8641
# epoch [42/50], loss:23.2672
# epoch [43/50], loss:0.6494
# epoch [44/50], loss:1.5343
# epoch [45/50], loss:0.8902
# epoch [46/50], loss:1.6057
# epoch [47/50], loss:0.6448
# epoch [48/50], loss:1.2793
# epoch [49/50], loss:0.6537
# epoch [50/50], loss:1.5202
# epoch [1/50], loss:1.6176
# epoch [2/50], loss:1.7010
# epoch [3/50], loss:2.0090
# epoch [4/50], loss:1.7506
# epoch [5/50], loss:3.2997
# epoch [6/50], loss:2.5078
# epoch [7/50], loss:1.6012
# epoch [8/50], loss:3.2570
# epoch [9/50], loss:2.0483
# epoch [10/50], loss:1.5298
# epoch [11/50], loss:2.1075
# epoch [12/50], loss:1.2715
# epoch [13/50], loss:1.5985
# epoch [14/50], loss:3.1836
# epoch [15/50], loss:1.8785
# epoch [16/50], loss:2.4696
# epoch [17/50], loss:1.5904
# epoch [18/50], loss:2.0397
# epoch [19/50], loss:1.7260
# epoch [20/50], loss:2.8658
# epoch [21/50], loss:1.6973
# epoch [22/50], loss:3.7158
# epoch [23/50], loss:1.4729
# epoch [24/50], loss:1.2742
# epoch [25/50], loss:1.5272
# epoch [26/50], loss:1.8942
# epoch [27/50], loss:1.7385
# epoch [28/50], loss:3.2049
# epoch [29/50], loss:1.5214
# epoch [30/50], loss:1.8312
# epoch [31/50], loss:1.6052
# epoch [32/50], loss:1.1685
# epoch [33/50], loss:1.7030
# epoch [34/50], loss:1.5889
# epoch [35/50], loss:1.1896
# epoch [36/50], loss:3.9915
# epoch [37/50], loss:1.3010
# epoch [38/50], loss:1.9022
# epoch [39/50], loss:1.6003
# ...
# epoch [5/50], loss:0.8024
# epoch [6/50], loss:0.8116
# epoch [7/50], loss:1.0000
# epoch [8/50], loss:0.7487
# epoch [9/50], loss:0.5432
# epoch [10/50], loss:0.4988
# epoch [11/50], loss:0.6731
# epoch [12/50], loss:0.5077
# epoch [13/50], loss:0.5127
# epoch [14/50], loss:0.4971
# epoch [15/50], loss:0.8739
# epoch [16/50], loss:0.6395
# epoch [17/50], loss:0.7069
# epoch [18/50], loss:0.4930
# epoch [19/50], loss:0.7494
# epoch [20/50], loss:0.7218
# epoch [21/50], loss:0.5474
# epoch [22/50], loss:0.6226
# epoch [23/50], loss:1.0021
# epoch [24/50], loss:0.6043
# epoch [25/50], loss:0.4999
# epoch [26/50], loss:0.8495
# epoch [27/50], loss:0.6027
# epoch [28/50], loss:0.7119
# epoch [29/50], loss:0.7690
# epoch [30/50], loss:0.5807
# epoch [31/50], loss:0.5119
# epoch [32/50], loss:0.9405
# epoch [33/50], loss:0.4985
# epoch [34/50], loss:1.2446
# epoch [35/50], loss:0.9157
# epoch [36/50], loss:0.5788
# epoch [37/50], loss:0.5111
# epoch [38/50], loss:0.7411
# epoch [39/50], loss:1.0797
# epoch [40/50], loss:1.0310
# epoch [41/50], loss:0.8690
# epoch [42/50], loss:0.8612
# epoch [43/50], loss:0.4894
# epoch [44/50], loss:1.0088
# epoch [45/50], loss:0.5109
# epoch [46/50], loss:0.7610
# epoch [47/50], loss:0.7136
# epoch [48/50], loss:0.7568
# epoch [49/50], loss:0.9768
# epoch [50/50], loss:0.9176
# epoch [1/50], loss:0.6841
# epoch [2/50], loss:0.7640
# epoch [3/50], loss:1.3698
# epoch [4/50], loss:0.5394
# epoch [5/50], loss:0.4345
# epoch [6/50], loss:0.8748
# epoch [7/50], loss:0.7426
# epoch [8/50], loss:0.5125
# epoch [9/50], loss:0.7108
# epoch [10/50], loss:0.6824
# epoch [11/50], loss:0.4511
# epoch [12/50], loss:0.8853
# epoch [13/50], loss:1.0504
# epoch [14/50], loss:0.4614
# epoch [15/50], loss:0.5370
# epoch [16/50], loss:0.5925
# epoch [17/50], loss:0.7235
# epoch [18/50], loss:0.9085
# epoch [19/50], loss:7.3622
# epoch [20/50], loss:1.2817
# epoch [21/50], loss:0.9669
# epoch [22/50], loss:0.8874
# epoch [23/50], loss:0.8066
# epoch [24/50], loss:1.4030
# epoch [25/50], loss:0.8539
# epoch [26/50], loss:0.9770
# epoch [27/50], loss:0.7408
# epoch [28/50], loss:0.9054
# epoch [29/50], loss:0.8940
# epoch [30/50], loss:1.0831
# epoch [31/50], loss:0.7247
# epoch [32/50], loss:0.7717
# epoch [33/50], loss:0.9016
# epoch [34/50], loss:0.7649
# epoch [35/50], loss:0.8876
# epoch [36/50], loss:0.7685
# epoch [37/50], loss:0.8966
# epoch [38/50], loss:0.8335
# epoch [39/50], loss:1.4578
# epoch [40/50], loss:0.7221
# epoch [41/50], loss:0.7126
# epoch [42/50], loss:0.8551
# epoch [43/50], loss:0.8045
# epoch [44/50], loss:0.7453
# epoch [45/50], loss:0.7422
# epoch [46/50], loss:1.4664
# epoch [47/50], loss:0.8434
# epoch [48/50], loss:0.7276
# epoch [49/50], loss:0.6902
# epoch [50/50], loss:0.8012
# epoch [1/50], loss:0.8114
# epoch [2/50], loss:0.8472
# epoch [3/50], loss:25.6395
# epoch [4/50], loss:0.7698
# epoch [5/50], loss:1.1948
# epoch [6/50], loss:3.4740
# epoch [7/50], loss:2.4793
# epoch [8/50], loss:2.8074
# epoch [9/50], loss:1.9909
# epoch [10/50], loss:3.3437
# epoch [11/50], loss:4.8444
# epoch [12/50], loss:2.5315
# epoch [13/50], loss:2.9399
# epoch [14/50], loss:2.0245
# epoch [15/50], loss:2.7950
# epoch [16/50], loss:0.6571
# epoch [17/50], loss:4.4786
# epoch [18/50], loss:2.8742
# epoch [19/50], loss:1.0253
# epoch [20/50], loss:0.8911
# epoch [21/50], loss:0.6589
# epoch [22/50], loss:0.8907
# epoch [23/50], loss:0.4488
# epoch [24/50], loss:0.7338
# epoch [25/50], loss:2.5145
# epoch [26/50], loss:2.2368
# epoch [27/50], loss:0.4487
# epoch [28/50], loss:1.0234
# epoch [29/50], loss:3.0131
# epoch [30/50], loss:3.2318
# epoch [31/50], loss:2.9296
# epoch [32/50], loss:3.5940
# epoch [33/50], loss:1.4016
# epoch [34/50], loss:8.4550
# epoch [35/50], loss:8.4683
# epoch [36/50], loss:4.1626
# epoch [37/50], loss:2.7079
# epoch [38/50], loss:2.8711
# epoch [39/50], loss:1.5283
# epoch [40/50], loss:0.8698
# epoch [41/50], loss:0.8917
# epoch [42/50], loss:2.0263
# epoch [43/50], loss:0.8537
# epoch [44/50], loss:0.8918
# epoch [45/50], loss:0.7334
# epoch [46/50], loss:0.9762
# epoch [47/50], loss:0.6629
# epoch [48/50], loss:2.9254
# epoch [49/50], loss:9.3840
# epoch [50/50], loss:0.6634
# epoch [1/50], loss:2.5101
# epoch [2/50], loss:0.9909
# epoch [3/50], loss:0.4342
# epoch [4/50], loss:2.3546
# epoch [5/50], loss:4.1049
# epoch [6/50], loss:6.0418
# epoch [7/50], loss:3.8032
# epoch [8/50], loss:1.3516
# epoch [9/50], loss:3.8960
# epoch [10/50], loss:1.3526
# epoch [11/50], loss:2.8070
# epoch [12/50], loss:6.3396
# epoch [13/50], loss:3.0396
# epoch [14/50], loss:0.9951
# epoch [15/50], loss:0.9952
# epoch [16/50], loss:3.5709
# epoch [17/50], loss:1.3557
# epoch [18/50], loss:3.2732
# epoch [19/50], loss:2.3436
# epoch [20/50], loss:0.4092
# epoch [21/50], loss:2.8121
# epoch [22/50], loss:0.6909
# epoch [23/50], loss:4.9245
# epoch [24/50], loss:0.5749
# epoch [25/50], loss:2.8123
# epoch [26/50], loss:1.0877
# epoch [27/50], loss:4.2310
# epoch [28/50], loss:2.9959
# epoch [29/50], loss:5.7243
# epoch [30/50], loss:0.5746
# epoch [31/50], loss:2.9158
# epoch [32/50], loss:4.4378
# epoch [33/50], loss:1.3609
# epoch [34/50], loss:1.6771
# epoch [35/50], loss:1.0873
# epoch [36/50], loss:0.4597
# epoch [37/50], loss:4.6472
# epoch [38/50], loss:0.4597
# epoch [39/50], loss:0.4596
# epoch [40/50], loss:3.3785
# epoch [41/50], loss:0.6899
# epoch [42/50], loss:1.3633
# epoch [43/50], loss:1.0867
# epoch [44/50], loss:3.3517
# epoch [45/50], loss:3.2762
# epoch [46/50], loss:2.7856
# epoch [47/50], loss:3.3310
# epoch [48/50], loss:0.4136
# epoch [49/50], loss:3.1486
# epoch [50/50], loss:2.8158
# epoch [1/50], loss:1.3512
# epoch [2/50], loss:1.3085
# epoch [3/50], loss:2.9145
# epoch [4/50], loss:1.9722
# epoch [5/50], loss:4.7258
# epoch [6/50], loss:2.7792
# epoch [7/50], loss:1.2413
# epoch [8/50], loss:2.5976
# epoch [9/50], loss:2.9354
# epoch [10/50], loss:4.9118
# epoch [11/50], loss:4.7650
# epoch [12/50], loss:1.1418
# epoch [13/50], loss:3.3802
# epoch [14/50], loss:0.9189
# epoch [15/50], loss:4.5436
# epoch [16/50], loss:3.3135
# epoch [17/50], loss:1.1414
# epoch [18/50], loss:1.2946
# epoch [19/50], loss:0.9171
# epoch [20/50], loss:2.2478
# epoch [21/50], loss:2.1186
# epoch [22/50], loss:0.8150
# epoch [23/50], loss:1.2958
# epoch [24/50], loss:4.2799
# epoch [25/50], loss:0.9152
# epoch [26/50], loss:0.9369
# epoch [27/50], loss:3.4349
# epoch [28/50], loss:4.2763
# epoch [29/50], loss:1.1549
# epoch [30/50], loss:1.2938
# epoch [31/50], loss:1.2935
# epoch [32/50], loss:3.8584
# epoch [33/50], loss:1.2931
# epoch [34/50], loss:2.5706
# epoch [35/50], loss:1.1396
# epoch [36/50], loss:3.2333
# epoch [37/50], loss:1.2919
# epoch [38/50], loss:2.2602
# epoch [39/50], loss:2.2615
# epoch [40/50], loss:2.6024
# epoch [41/50], loss:2.5995
# epoch [42/50], loss:2.9475
# epoch [43/50], loss:2.5709
# epoch [44/50], loss:0.9096
# epoch [45/50], loss:2.6017
# epoch [46/50], loss:1.7595
# epoch [47/50], loss:2.9292
# epoch [48/50], loss:1.3549
# epoch [49/50], loss:1.3545
# epoch [50/50], loss:1.1479
# epoch [1/50], loss:1.4314
# epoch [2/50], loss:1.4225
# epoch [3/50], loss:1.4673
# epoch [4/50], loss:0.3928
# epoch [5/50], loss:1.6627
# epoch [6/50], loss:1.4950
# epoch [7/50], loss:1.4543
# epoch [8/50], loss:5.1361
# epoch [9/50], loss:5.5316
# epoch [10/50], loss:2.9468
# epoch [11/50], loss:0.3922
# epoch [12/50], loss:4.8106
# epoch [13/50], loss:2.4593
# epoch [14/50], loss:0.5512
# epoch [15/50], loss:2.1686
# epoch [16/50], loss:1.6634
# epoch [17/50], loss:1.6637
# epoch [18/50], loss:4.7867
# epoch [19/50], loss:6.4973
# epoch [20/50], loss:6.5001
# epoch [21/50], loss:1.0830
# epoch [22/50], loss:0.5507
# epoch [23/50], loss:0.5506
# epoch [24/50], loss:4.4848
# epoch [25/50], loss:0.3907
# epoch [26/50], loss:1.0820
# epoch [27/50], loss:2.1411
# epoch [28/50], loss:1.4838
# epoch [29/50], loss:3.8260
# epoch [30/50], loss:2.1676
# epoch [31/50], loss:3.0743
# epoch [32/50], loss:1.0892
# epoch [33/50], loss:0.6470
# epoch [34/50], loss:0.5498
# epoch [35/50], loss:3.0461
# epoch [36/50], loss:0.3895
# epoch [37/50], loss:2.8637
# epoch [38/50], loss:5.5742
# epoch [39/50], loss:3.0499
# epoch [40/50], loss:0.8566
# epoch [41/50], loss:1.4751
# epoch [42/50], loss:3.7540
# epoch [43/50], loss:0.8563
# epoch [44/50], loss:2.1417
# epoch [45/50], loss:0.5489
# epoch [46/50], loss:4.3387
# epoch [47/50], loss:3.0335
# epoch [48/50], loss:0.3881
# epoch [49/50], loss:0.3880
# epoch [50/50], loss:1.6623
# epoch [1/50], loss:0.9572
# epoch [2/50], loss:0.7803
# epoch [3/50], loss:1.8143
# epoch [4/50], loss:0.7799
# epoch [5/50], loss:0.9681
# epoch [6/50], loss:0.7792
# epoch [7/50], loss:2.9735
# epoch [8/50], loss:1.3690
# epoch [9/50], loss:0.9530
# epoch [10/50], loss:0.9459
# epoch [11/50], loss:2.3917
# epoch [12/50], loss:0.7766
# epoch [13/50], loss:1.1481
# epoch [14/50], loss:2.8999
# epoch [15/50], loss:0.9755
# epoch [16/50], loss:2.1209
# epoch [17/50], loss:1.9012
# epoch [18/50], loss:0.9423
# epoch [19/50], loss:1.7886
# epoch [20/50], loss:2.8358
# epoch [21/50], loss:0.9794
# epoch [22/50], loss:1.8076
# epoch [23/50], loss:1.7332
# epoch [24/50], loss:1.3663
# epoch [25/50], loss:2.3798
# epoch [26/50], loss:1.1398
# epoch [27/50], loss:0.9488
# epoch [28/50], loss:1.2399
# epoch [29/50], loss:1.7555
# epoch [30/50], loss:2.3783
# epoch [31/50], loss:0.9856
# epoch [32/50], loss:0.9706
# epoch [33/50], loss:1.1372
# epoch [34/50], loss:0.7680
# epoch [35/50], loss:0.9406
# epoch [36/50], loss:3.0082
# epoch [37/50], loss:2.1012
# epoch [38/50], loss:3.0115
# epoch [39/50], loss:0.9458
# epoch [40/50], loss:1.5073
# epoch [41/50], loss:2.0976
# epoch [42/50], loss:1.3557
# epoch [43/50], loss:1.7862
# epoch [44/50], loss:0.9736
# epoch [45/50], loss:0.9663
# epoch [46/50], loss:0.9662
# epoch [47/50], loss:0.9703
# epoch [48/50], loss:0.9657
# epoch [49/50], loss:2.5490
# epoch [50/50], loss:1.7896
# epoch [1/50], loss:0.8858
# epoch [2/50], loss:1.1828
# epoch [3/50], loss:1.0862
# epoch [4/50], loss:1.0858
# epoch [5/50], loss:0.7494
# epoch [6/50], loss:0.7251
# epoch [7/50], loss:0.8886
# epoch [8/50], loss:1.2244
# epoch [9/50], loss:1.1154
# epoch [10/50], loss:1.2309
# epoch [11/50], loss:1.3881
# epoch [12/50], loss:0.8836
# epoch [13/50], loss:0.5154
# epoch [14/50], loss:0.8833
# epoch [15/50], loss:0.8841
# epoch [16/50], loss:1.2390
# epoch [17/50], loss:0.7035
# epoch [18/50], loss:1.0847
# epoch [19/50], loss:0.8888
# epoch [20/50], loss:0.7123
# epoch [21/50], loss:1.0607
# epoch [22/50], loss:2.5128
# epoch [23/50], loss:2.5565
# epoch [24/50], loss:0.7104
# epoch [25/50], loss:0.8892
# epoch [26/50], loss:2.5443
# epoch [27/50], loss:0.5148
# epoch [28/50], loss:0.8835
# epoch [29/50], loss:1.2673
# epoch [30/50], loss:0.7057
# epoch [31/50], loss:1.0838
# epoch [32/50], loss:0.8889
# epoch [33/50], loss:0.8112
# epoch [34/50], loss:1.0838
# epoch [35/50], loss:0.6376
# epoch [36/50], loss:0.7030
# epoch [37/50], loss:0.7219
# epoch [38/50], loss:0.8830
# epoch [39/50], loss:0.7938
# epoch [40/50], loss:1.0490
# epoch [41/50], loss:2.3501
# epoch [42/50], loss:0.6373
# epoch [43/50], loss:0.6665
# epoch [44/50], loss:1.0296
# epoch [45/50], loss:0.6673
# epoch [46/50], loss:1.0571
# epoch [47/50], loss:2.1284
# epoch [48/50], loss:0.7119
# epoch [49/50], loss:1.0828
# epoch [50/50], loss:0.7927
# epoch [1/50], loss:6.4357
# epoch [2/50], loss:0.4518
# epoch [3/50], loss:1.1613
# epoch [4/50], loss:1.4812
# epoch [5/50], loss:0.8468
# epoch [6/50], loss:0.7640
# epoch [7/50], loss:0.7255
# epoch [8/50], loss:1.3873
# epoch [9/50], loss:0.4506
# epoch [10/50], loss:0.7447
# epoch [11/50], loss:0.6126
# epoch [12/50], loss:0.6023
# epoch [13/50], loss:0.4499
# epoch [14/50], loss:0.7428
# epoch [15/50], loss:1.3728
# epoch [16/50], loss:1.3878
# epoch [17/50], loss:1.0151
# epoch [18/50], loss:0.8919
# epoch [19/50], loss:0.4493
# epoch [20/50], loss:0.7639
# epoch [21/50], loss:0.8429
# epoch [22/50], loss:0.6381
# epoch [23/50], loss:0.7021
# epoch [24/50], loss:0.7020
# epoch [25/50], loss:0.5530
# epoch [26/50], loss:0.6244
# epoch [27/50], loss:0.4629
# epoch [28/50], loss:0.4628
# epoch [29/50], loss:0.7630
# epoch [30/50], loss:0.5534
# epoch [31/50], loss:1.8330
# epoch [32/50], loss:1.3581
# epoch [33/50], loss:1.8275
# epoch [34/50], loss:0.7294
# epoch [35/50], loss:0.8383
# epoch [36/50], loss:0.8344
# epoch [37/50], loss:1.3430
# epoch [38/50], loss:0.8339
# epoch [39/50], loss:0.5983
# epoch [40/50], loss:1.3686
# epoch [41/50], loss:0.7251
# epoch [42/50], loss:0.7626
# epoch [43/50], loss:0.5553
# epoch [44/50], loss:1.7908
# epoch [45/50], loss:0.7249
# epoch [46/50], loss:0.7612
# epoch [47/50], loss:0.7748
# epoch [48/50], loss:0.6218
# epoch [49/50], loss:0.7124
# epoch [50/50], loss:0.6217
# epoch [1/50], loss:0.4500
# epoch [2/50], loss:0.6841
# epoch [3/50], loss:1.0171
# epoch [4/50], loss:0.4347
# epoch [5/50], loss:0.4346
# epoch [6/50], loss:0.5431
# epoch [7/50], loss:0.4345
# epoch [8/50], loss:0.9122
# epoch [9/50], loss:0.9121
# epoch [10/50], loss:0.7943
# epoch [11/50], loss:1.2414
# epoch [12/50], loss:0.5791
# epoch [13/50], loss:1.1187
# epoch [14/50], loss:0.4335
# epoch [15/50], loss:0.5406
# epoch [16/50], loss:1.1187
# epoch [17/50], loss:0.4331
# epoch [18/50], loss:0.5396
# epoch [19/50], loss:1.2558
# epoch [20/50], loss:1.2550
# epoch [21/50], loss:0.5386
# epoch [22/50], loss:0.7790
# epoch [23/50], loss:1.2146
# epoch [24/50], loss:1.4139
# epoch [25/50], loss:0.5821
# epoch [26/50], loss:0.5660
# epoch [27/50], loss:1.4123
# epoch [28/50], loss:0.5363
# epoch [29/50], loss:0.8440
# epoch [30/50], loss:1.4108
# epoch [31/50], loss:0.7703
# epoch [32/50], loss:1.1981
# epoch [33/50], loss:0.9091
# epoch [34/50], loss:0.8474
# epoch [35/50], loss:1.1917
# epoch [36/50], loss:0.4676
# epoch [37/50], loss:0.9089
# epoch [38/50], loss:0.8506
# epoch [39/50], loss:0.8506
# epoch [40/50], loss:1.4060
# epoch [41/50], loss:1.1188
# epoch [42/50], loss:0.7596
# epoch [43/50], loss:0.8535
# epoch [44/50], loss:0.7580
# epoch [45/50], loss:1.3854
# epoch [46/50], loss:0.8554
# epoch [47/50], loss:1.4026
# epoch [48/50], loss:0.7552
# epoch [49/50], loss:0.8570
# epoch [50/50], loss:1.2380
# epoch [1/50], loss:0.7005
# epoch [2/50], loss:0.9138
# epoch [3/50], loss:0.7037
# epoch [4/50], loss:0.6936
# epoch [5/50], loss:0.4447
# epoch [6/50], loss:0.8304
# epoch [7/50], loss:0.6490
# epoch [8/50], loss:0.4433
# epoch [9/50], loss:0.8066
# epoch [10/50], loss:0.7005
# epoch [11/50], loss:0.7043
# epoch [12/50], loss:0.4663
# epoch [13/50], loss:0.6318
# epoch [14/50], loss:0.8642
# epoch [15/50], loss:0.5131
# epoch [16/50], loss:0.6539
# epoch [17/50], loss:0.6742
# epoch [18/50], loss:0.6314
# epoch [19/50], loss:0.6873
# epoch [20/50], loss:0.6872
# epoch [21/50], loss:0.6986
# epoch [22/50], loss:0.8756
# epoch [23/50], loss:0.6311
# epoch [24/50], loss:0.7498
# epoch [25/50], loss:0.7476
# epoch [26/50], loss:0.4611
# epoch [27/50], loss:0.6738
# epoch [28/50], loss:0.8680
# epoch [29/50], loss:0.6737
# epoch [30/50], loss:0.6999
# epoch [31/50], loss:0.8632
# epoch [32/50], loss:0.7386
# epoch [33/50], loss:0.4702
# epoch [34/50], loss:0.4367
# epoch [35/50], loss:0.7533
# epoch [36/50], loss:0.3861
# epoch [37/50], loss:0.3860
# epoch [38/50], loss:0.4627
# epoch [39/50], loss:0.7432
# epoch [40/50], loss:0.7425
# epoch [41/50], loss:0.6960
# epoch [42/50], loss:0.3862
# epoch [43/50], loss:0.6857
# epoch [44/50], loss:0.3862
# epoch [45/50], loss:0.7636
# epoch [46/50], loss:0.7666
# epoch [47/50], loss:0.6953
# epoch [48/50], loss:0.8333
# epoch [49/50], loss:0.6855
# epoch [50/50], loss:0.8445
# epoch [1/50], loss:0.5298
# epoch [2/50], loss:0.4764
# epoch [3/50], loss:0.4988
# epoch [4/50], loss:0.5334
# epoch [5/50], loss:0.3906
# epoch [6/50], loss:0.6760
# epoch [7/50], loss:0.4554
# epoch [8/50], loss:1.5011
# epoch [9/50], loss:0.4555
# epoch [10/50], loss:0.4072
# epoch [11/50], loss:0.7134
# epoch [12/50], loss:0.5338
# epoch [13/50], loss:0.7611
# epoch [14/50], loss:0.5274
# epoch [15/50], loss:0.5334
# epoch [16/50], loss:0.4190
# epoch [17/50], loss:0.5332
# epoch [18/50], loss:0.6839
# epoch [19/50], loss:0.8487
# epoch [20/50], loss:0.4564
# epoch [21/50], loss:0.5211
# epoch [22/50], loss:0.4717
# epoch [23/50], loss:0.5673
# epoch [24/50], loss:0.8338
# epoch [25/50], loss:0.4979
# epoch [26/50], loss:0.4820
# epoch [27/50], loss:0.5319
# epoch [28/50], loss:0.4586
# epoch [29/50], loss:0.9837
# epoch [30/50], loss:0.4761
# epoch [31/50], loss:1.5449
# epoch [32/50], loss:0.6559
# epoch [33/50], loss:0.6557
# epoch [34/50], loss:1.5899
# epoch [35/50], loss:0.4209
# epoch [36/50], loss:1.0061
# epoch [37/50], loss:0.4802
# epoch [38/50], loss:0.4175
# epoch [39/50], loss:0.5197
# epoch [40/50], loss:0.5193
# epoch [41/50], loss:0.4762
# epoch [42/50], loss:0.9827
# epoch [43/50], loss:0.5111
# epoch [44/50], loss:1.4337
# epoch [45/50], loss:0.5813
# epoch [46/50], loss:0.4786
# epoch [47/50], loss:0.5342
# epoch [48/50], loss:0.7766
# epoch [49/50], loss:0.3866
# epoch [50/50], loss:0.4654

# %%
Testspectrum = []
Testspectra = []
Testexcitation = torch.tensor([])
for i in range(50):
    Testspectrum.append(PhonemeSamples["A"].spectrum)
    Testspectra.append(PhonemeSamples["A"].spectra[i])
for i in range(50 * PhonemeSamples["A"].Pitch):
    Testexcitation = torch.cat((Testexcitation, PhonemeSamples["A"].excitation[i].unsqueeze(0)), dim=0)
    
for i in range(40):
    Testspectrum.append(PhonemeSamples["N"].spectrum)
    Testspectra.append(PhonemeSamples["N"].spectra[i + 0])
for i in range(0, 40 * PhonemeSamples["N"].Pitch + 0):
    Testexcitation = torch.cat((Testexcitation, PhonemeSamples["N"].excitation[i].unsqueeze(0)), dim=0)
    
for i in range(50):
    Testspectrum.append(PhonemeSamples["A"].spectrum)
    Testspectra.append(PhonemeSamples["A"].spectra[i + 70])
for i in range(70, 50 * PhonemeSamples["A"].Pitch + 70):
    Testexcitation = torch.cat((Testexcitation, PhonemeSamples["A"].excitation[i].unsqueeze(0)), dim=0)
    
for i in range(20):
    Testspectrum.append(PhonemeSamples["T"].spectrum)
    Testspectra.append(PhonemeSamples["T"].spectra[i + 0])
for i in range(0, 20 * PhonemeSamples["T"].Pitch + 0):
    Testexcitation = torch.cat((Testexcitation, PhonemeSamples["T"].excitation[i].unsqueeze(0)), dim=0)
    
for i in range(50):
    Testspectrum.append(PhonemeSamples["A"].spectrum)
    Testspectra.append(PhonemeSamples["A"].spectra[i + 154])
for i in range(154, 50 * PhonemeSamples["A"].Pitch + 154):
    Testexcitation = torch.cat((Testexcitation, PhonemeSamples["A"].excitation[i].unsqueeze(0)), dim=0)
    
for i in range(40, 60):
    Testspectrum[i] = specCrfAi.processData(Testspectrum[39], Testspectrum[60], 0.05 * (i - 40))
    
for i in range(85, 95):
    Testspectrum[i] = specCrfAi.processData(Testspectrum[84], Testspectrum[95], 0.1 * (i - 85))
    
for i in range(135, 145):
    Testspectrum[i] = specCrfAi.processData(Testspectrum[134], Testspectrum[145], 0.1 * (i - 135))
    
for i in range(155, 165):
    Testspectrum[i] = specCrfAi.processData(Testspectrum[154], Testspectrum[165], 0.1 * (i - 155))

# %%
synthesizer2 = Synthesizer2(PhonemeSamples["A"].sampleRate)
synthesizer2.SynthesizeBatch(-1., Testspectrum, Testspectra, Testexcitation)
synthesizer2.save("Output_S2.wav")

# %%
plt.plot(PhonemeSamples["A"].spectrum)
